# %% [markdown]
# # Local Multi-Speaker Voice Processing Demo
#
# This notebook runs the fully local voice processing pipeline from `audio.wav`, a local video file, or a YouTube URL.
#
# - loads and normalizes audio to 16 kHz mono
# - segments speech with Silero VAD
# - extracts SpeechBrain ECAPA speaker embeddings
# - clusters speakers with explicit agglomerative clustering
# - transcribes with local Whisper
# - emits speaker-labeled transcript JSON
#
# Optional: if you provide a YouTube URL, the notebook downloads audio locally with `yt-dlp`, converts it to 16 kHz mono WAV with `ffmpeg`, and runs the same pipeline on that extracted audio. If you provide a local video file, it extracts audio with `ffmpeg`. If you also provide `user_voice.wav`, the pipeline will label matching turns as `USER`. Without it, output labels stay as `Speaker_0`, `Speaker_1`, etc.
#
# Install the optional local speech stack before running model-backed cells:
#
# ```bash
# pip install -e '.[voice-processing]'
# ```

# %%
from pathlib import Path

import json
import shutil
import subprocess
import sys


PROJECT_ROOT = Path.cwd()
DEFAULT_AUDIO_PATH = PROJECT_ROOT / "youtube_audio.wav"
if not DEFAULT_AUDIO_PATH.exists() and (PROJECT_ROOT / "tests" / "youtube_audio.wav").exists():
    DEFAULT_AUDIO_PATH = PROJECT_ROOT / "tests" / "youtube_audio.wav"
AUDIO_PATH = DEFAULT_AUDIO_PATH
YOUTUBE_URL = None  # Already downloaded from https://www.youtube.com/watch?v=gNA2fQ2KAIs
VIDEO_PATH = None  # Example: PROJECT_ROOT / "meeting.mp4"
YOUTUBE_COOKIES_FROM_BROWSER = None  # Example: "chrome", "safari", or "firefox" for restricted videos.
EXTRACTED_AUDIO_PATH = PROJECT_ROOT / "extracted_audio.wav"
YOUTUBE_DOWNLOAD_STEM = PROJECT_ROOT / "youtube_downloaded_audio"
YOUTUBE_AUDIO_PATH = PROJECT_ROOT / "youtube_audio.wav"
OPTIONAL_USER_VOICE_PATH = PROJECT_ROOT / "user_voice.wav"
USER_VOICE_PATH = OPTIONAL_USER_VOICE_PATH if OPTIONAL_USER_VOICE_PATH.exists() else None
OUTPUT_JSON_PATH = PROJECT_ROOT / "voice_transcript.json"

print("audio:", AUDIO_PATH)
print("youtube url:", YOUTUBE_URL)
print("video:", VIDEO_PATH)
print("youtube cookies browser:", YOUTUBE_COOKIES_FROM_BROWSER)
print("extracted audio:", EXTRACTED_AUDIO_PATH)
print("youtube audio:", YOUTUBE_AUDIO_PATH)
print("optional user voice:", USER_VOICE_PATH)
print("output:", OUTPUT_JSON_PATH)
# Out:
# audio: /Users/saketm10/Projects/openclaw_agents/tests/youtube_audio.wav
# youtube url: None
# video: None
# youtube cookies browser: None
# extracted audio: /Users/saketm10/Projects/openclaw_agents/tests/extracted_audio.wav
# youtube audio: /Users/saketm10/Projects/openclaw_agents/tests/youtube_audio.wav
# optional user voice: None
# output: /Users/saketm10/Projects/openclaw_agents/tests/voice_transcript.json

# %%
def require_ffmpeg() -> None:
    if shutil.which("ffmpeg") is None:
        raise RuntimeError("ffmpeg is required for media extraction. Install ffmpeg and rerun this cell.")


def convert_to_pipeline_wav(input_path: Path, audio_path: Path) -> Path:
    require_ffmpeg()
    command = [
        "ffmpeg",
        "-y",
        "-i",
        str(input_path),
        "-vn",
        "-ac",
        "1",
        "-ar",
        "16000",
        "-sample_fmt",
        "s16",
        str(audio_path),
    ]
    subprocess.run(command, check=True)
    return audio_path


def extract_audio_from_video(video_path: Path, audio_path: Path) -> Path:
    if not video_path.exists():
        raise FileNotFoundError(f"Missing video file: {video_path}")
    return convert_to_pipeline_wav(video_path, audio_path)


def extract_audio_from_youtube(youtube_url: str, audio_path: Path) -> Path:
    require_ffmpeg()
    if not youtube_url.startswith(("http://", "https://")) or "youtube" not in youtube_url and "youtu.be" not in youtube_url:
        raise ValueError(f"YOUTUBE_URL does not look like a full YouTube URL: {youtube_url!r}")

    if shutil.which("yt-dlp") is None:
        try:
            import yt_dlp  # noqa: F401
        except ImportError as error:
            raise RuntimeError("yt-dlp is required for YouTube input. Install with: pip install yt-dlp") from error

    for stale_path in YOUTUBE_DOWNLOAD_STEM.parent.glob(YOUTUBE_DOWNLOAD_STEM.name + ".*"):
        stale_path.unlink()

    command = [
        sys.executable,
        "-m",
        "yt_dlp",
        "--no-playlist",
        "--newline",
        "-f",
        "bestaudio/best",
        "--extract-audio",
        "--audio-format",
        "m4a",
        "-o",
        str(YOUTUBE_DOWNLOAD_STEM) + ".%(ext)s",
    ]
    if YOUTUBE_COOKIES_FROM_BROWSER:
        command.extend(["--cookies-from-browser", YOUTUBE_COOKIES_FROM_BROWSER])
    command.append(youtube_url)

    result = subprocess.run(command, capture_output=True, text=True)
    if result.returncode != 0:
        stdout_tail = result.stdout[-4000:]
        stderr_tail = result.stderr[-4000:]
        print("yt-dlp stdout:\n", stdout_tail)
        print("yt-dlp stderr:\n", stderr_tail)
        raise RuntimeError(
            "yt-dlp failed with exit code "
            f"{result.returncode}.\n\nSTDERR tail:\n{stderr_tail}\n\n"
            "Common fixes: update yt-dlp, verify the URL, or set "
            "YOUTUBE_COOKIES_FROM_BROWSER='chrome'/'safari'/'firefox' for restricted videos."
        )

    candidates = sorted(YOUTUBE_DOWNLOAD_STEM.parent.glob(YOUTUBE_DOWNLOAD_STEM.name + ".*"))
    if not candidates:
        raise FileNotFoundError("yt-dlp finished but no downloaded audio file was found.")
    downloaded_path = candidates[0]
    print("downloaded YouTube audio:", downloaded_path)
    return convert_to_pipeline_wav(downloaded_path, audio_path)

if YOUTUBE_URL:
    EFFECTIVE_AUDIO_PATH = extract_audio_from_youtube(YOUTUBE_URL, YOUTUBE_AUDIO_PATH)
elif VIDEO_PATH is not None:
    EFFECTIVE_AUDIO_PATH = extract_audio_from_video(Path(VIDEO_PATH), EXTRACTED_AUDIO_PATH)
elif AUDIO_PATH.exists():
    EFFECTIVE_AUDIO_PATH = AUDIO_PATH
else:
    raise FileNotFoundError(f"Missing input audio file: {AUDIO_PATH}. Set YOUTUBE_URL or VIDEO_PATH to extract audio.")

print("pipeline audio:", EFFECTIVE_AUDIO_PATH)

if USER_VOICE_PATH is None:
    print("Running clustering-only diarization. No USER enrollment file found.")
else:
    print("Running diarization with USER enrollment:", USER_VOICE_PATH)
# Out:
# pipeline audio: /Users/saketm10/Projects/openclaw_agents/tests/youtube_audio.wav
# Running clustering-only diarization. No USER enrollment file found.

# %%
import importlib.util

required_modules = {
    "torch": "torch",
    "torchaudio": "torchaudio",
    "silero_vad": "silero-vad",
    "speechbrain": "speechbrain",
    "whisper": "openai-whisper",
}

missing = [package for module, package in required_modules.items() if importlib.util.find_spec(module) is None]
if missing:
    raise RuntimeError(
        "Missing local voice-processing dependencies: "
        + ", ".join(missing)
        + ". Install with: pip install -e '.[voice-processing]'"
    )

print("All local model dependencies are importable.")
# Out:
# All local model dependencies are importable.

# %%
from voice_processing import PipelineConfig, VoiceProcessingPipeline

config = PipelineConfig(
    whisper_model_name="small",
    language=None,
    output_json_path=OUTPUT_JSON_PATH,
    vad_threshold=0.5,
    min_segment_s=0.6,
    max_segment_s=3.0,
    preferred_segment_s=2.0,
    user_similarity_threshold=0.7,
    speaker_assignment_strategy="unique_speaker_similarity",
    speaker_similarity_threshold=0.5,
    cluster_distance_threshold=0.4,
    asr_chunk_s=28.0,
)

print(config)
print("device:", config.resolve_device())
# Out:
# PipelineConfig(sample_rate=16000, vad_threshold=0.5, vad_min_silence_ms=250, vad_min_speech_ms=200, vad_max_speech_s=18.0, preferred_segment_s=2.0, min_segment_s=0.6, max_segment_s=3.0, embedding_batch_size=16, user_similarity_threshold=0.7, user_margin_threshold=0.04, speaker_assignment_strategy='unique_speaker_similarity', speaker_similarity_threshold=0.5, cluster_distance_threshold=0.4, cluster_min_size=1, whisper_model_name='small', whisper_device=None, whisper_compute_type='float16', asr_chunk_s=28.0, asr_chunk_padding_s=0.2, language=None, output_json_path=PosixPath('/Users/saketm10/Projects/openclaw_agents/tests/voice_transcript.json'))
# device: cpu

# %%
pipeline = VoiceProcessingPipeline(config=config)
transcript = pipeline.run(EFFECTIVE_AUDIO_PATH, USER_VOICE_PATH)

print("Speaker assignment after similarity matching:")
for decision in pipeline.speaker_assignment_decisions:
    if decision.similarity is None or decision.confidence is None:
        print(f"{decision.provisional_speaker} assigned to {decision.assigned_speaker} (first unique speaker)")
        continue
    action = "matched existing" if decision.matched_existing else "created new speaker"
    print(
        f"{decision.provisional_speaker} assigned to {decision.assigned_speaker} "
        f"({action}, similarity={decision.similarity:.4f}, "
        f"threshold={decision.threshold:.4f}, confidence={decision.confidence:.4f})"
    )

transcript[:3]
# Out:
# [{'start': 0.0,
#   'end': 4.18,
#   'speaker': 'Speaker_0',
#   'text': 'Most people are not even using 1 % of what Google'},
#  {'start': 4.18, 'end': 4.76, 'speaker': 'Speaker_1', 'text': 'has built.'},
#  {'start': 6.49,
#   'end': 20.43,
#   'speaker': 'Speaker_0',
#   'text': "While the whole world has been focused on a damn chatbot, Google has been building something much, much larger. I'm talking about a tool where you can enter 100 pages of notes and it converts all of that into a cinematic video in just 60 seconds."}]

# %%
print(json.dumps(transcript, indent=2))
# Out:
# [
#   {
#     "start": 0.0,
#     "end": 4.18,
#     "speaker": "Speaker_0",
#     "text": "Most people are not even using 1 % of what Google"
#   },
#   {
#     "start": 4.18,
#     "end": 4.76,
#     "speaker": "Speaker_1",
#     "text": "has built."
#   },
#   {
#     "start": 6.49,
#     "end": 20.43,
#     "speaker": "Speaker_0",
#     "text": "While the whole world has been focused on a damn chatbot, Google has been building something much, much larger. I'm talking about a tool where you can enter 100 pages of notes and it converts all of that into a cinematic video in just 60 seconds."
#   },
#   {
#     "start": 20.67,
#     "end": 21.51,
#     "speaker": "Speaker_2",
#     "text": "A tool where"
#   },
#   {
#     "start": 21.51,
#     "end": 29.45,
#     "speaker": "Speaker_0",
#     "text": "you can just enter one sentence and convert the whole thing into a fully working app in just a few minutes. And there's one"
#   },
#   {
#     "start": 29.45,
#     "end": 31.17,
#     "speaker": "Speaker_3",
#     "text": "tool where you can just enter your"
#   },
#   {
#     "start": 31.17,
#     "end": 39.45,
#     "speaker": "Speaker_0",
#     "text": "website's URL and in one click, it will generate the whole week's marketing on the go. Now here is what is different about this video. You know"
#   },
#   {
#     "start": 39.45,
#     "end": 41.49,
#     "speaker": "Speaker_4",
#     "text": "that I don't usually show up like this."
#   },
#   {
#     "start": 41.77,
#     "end": 47.49,
#     "speaker": "Speaker_0",
#     "text": "It's usually my AI clone that creates all the content for me. Of course, my thoughts are real."
#   },
#   {
#     "start": 47.77,
#     "end": 49.43,
#     "speaker": "Speaker_5",
#     "text": "But for this video, it had"
#   },
#   {
#     "start": 49.43,
#     "end": 50.01,
#     "speaker": "Speaker_6",
#     "text": "to be different."
#   },
#   {
#     "start": 50.53,
#     "end": 53.05,
#     "speaker": "Speaker_0",
#     "text": "So I flew to meet someone very interesting."
#   },
#   {
#     "start": 53.55,
#     "end": 54.89,
#     "speaker": "Speaker_7",
#     "text": "Meet Josh Woodward."
#   },
#   {
#     "start": 55.25,
#     "end": 65.39,
#     "speaker": "Speaker_0",
#     "text": "He is the person behind Google Gemini. He is also the person who runs the Google Gemini. Google LAMP team that built notebook LAMP and of course he is also the person behind Google AI"
#   },
#   {
#     "start": 65.39,
#     "end": 67.89,
#     "speaker": "Speaker_8",
#     "text": "Studio. In fact Time magazine just"
#   },
#   {
#     "start": 67.89,
#     "end": 71.85,
#     "speaker": "Speaker_0",
#     "text": "rated him as one of the top 100 most influential AI"
#   },
#   {
#     "start": 71.85,
#     "end": 72.97,
#     "speaker": "Speaker_9",
#     "text": "figures in the world."
#   },
#   {
#     "start": 73.33,
#     "end": 91.806,
#     "speaker": "Speaker_0",
#     "text": "We didn't just talk about it, I asked him to show me things live in front of a camera. And if you're wondering this is some basic tutorial, guess what it's not. Josh ended up speaking about something that is still being built and most people in the world haven't heard about it. And you know what? You're gonna hear all about it."
#   },
#   {
#     "start": 92.066,
#     "end": 93.126,
#     "speaker": "Speaker_10",
#     "text": "So, let's get started."
#   },
#   {
#     "start": 94.166,
#     "end": 96.306,
#     "speaker": "Speaker_0",
#     "text": "Okay Josh, first of all, thank you very much for"
#   },
#   {
#     "start": 96.306,
#     "end": 98.306,
#     "speaker": "Speaker_11",
#     "text": "doing this. Very excited. Good to see you in"
#   },
#   {
#     "start": 98.306,
#     "end": 100.186,
#     "speaker": "Speaker_12",
#     "text": "flesh. Because I've been seeing on Twitter."
#   },
#   {
#     "start": 101.506,
#     "end": 102.266,
#     "speaker": "Speaker_13",
#     "text": "Right? That was great"
#   },
#   {
#     "start": 102.266,
#     "end": 104.306,
#     "speaker": "Speaker_14",
#     "text": "to meet you, first of all. Absolutely. So"
#   },
#   {
#     "start": 104.306,
#     "end": 106.406,
#     "speaker": "Speaker_0",
#     "text": "first question that I have is, you have a very interesting"
#   },
#   {
#     "start": 106.406,
#     "end": 110.326,
#     "speaker": "Speaker_15",
#     "text": "job. You run the Gemini app, the Gemini team, and you also"
#   },
#   {
#     "start": 110.326,
#     "end": 110.926,
#     "speaker": "Speaker_16",
#     "text": "run the labs."
#   },
#   {
#     "start": 111.346,
#     "end": 111.586,
#     "speaker": "Speaker_17",
#     "text": "Right."
#   },
#   {
#     "start": 112.602,
#     "end": 114.842,
#     "speaker": "Speaker_0",
#     "text": "My question is what keeps you awake? Is that"
#   },
#   {
#     "start": 114.842,
#     "end": 116.662,
#     "speaker": "Speaker_15",
#     "text": "the Gemini team that keeps you awake or the labs?"
#   },
#   {
#     "start": 116.782,
#     "end": 120.882,
#     "speaker": "Speaker_0",
#     "text": "Because you guys have been shipping at a velocity which is unprecedented. I don't"
#   },
#   {
#     "start": 120.882,
#     "end": 122.602,
#     "speaker": "Speaker_18",
#     "text": "have a different word for this. Yes, yes, yes."
#   },
#   {
#     "start": 123.262,
#     "end": 124.702,
#     "speaker": "Speaker_19",
#     "text": "I actually sleep pretty well right"
#   },
#   {
#     "start": 124.702,
#     "end": 124.922,
#     "speaker": "Speaker_20",
#     "text": "now."
#   },
#   {
#     "start": 126.062,
#     "end": 126.862,
#     "speaker": "Speaker_20",
#     "text": "I mean,"
#   },
#   {
#     "start": 127.042,
#     "end": 129.922,
#     "speaker": "Speaker_21",
#     "text": "both are extremely fun. They're full on for sure."
#   },
#   {
#     "start": 131.102,
#     "end": 132.822,
#     "speaker": "Speaker_22",
#     "text": "But no, they don't keep me up."
#   },
#   {
#     "start": 133.022,
#     "end": 135.042,
#     "speaker": "Speaker_23",
#     "text": "There's a lot to ship though."
#   },
#   {
#     "start": 135.522,
#     "end": 142.986,
#     "speaker": "Speaker_21",
#     "text": "I feel like it's one of the best parts of the job right now. Every week there's some new capability. capability and is how do you kind of turn it into a product or a feature and get it out."
#   },
#   {
#     "start": 144.006,
#     "end": 145.426,
#     "speaker": "Speaker_0",
#     "text": "Look, one thing that is happening"
#   },
#   {
#     "start": 145.426,
#     "end": 178.148,
#     "speaker": "Speaker_15",
#     "text": "is every time you ship a new labs product, every time you ship a new feature inside of Gemini, there is one narrative that propels across the internet and that is, oh, Pomele is going to replace marketers, oh, Liriya is going to replace a lot of music people, right? Anti -gravity is going to replace a lot of engineers. So there is this narrative built across AI that's going to replace a a lot of people people. and everything around it. So my big question that I have for you is to all those people who are worried, what is one line of advice that you have for everyone? And what do you think people should do to win in the AI first world?"
#   },
#   {
#     "start": 178.528,
#     "end": 180.128,
#     "speaker": "Speaker_24",
#     "text": "Yeah, well it's interesting because how we"
#   },
#   {
#     "start": 180.128,
#     "end": 190.188,
#     "speaker": "Speaker_19",
#     "text": "think of a lot of these tools, they are tools actually. And so a lot of what we do, one of our values on both the teams is we talk about how we co -create. So whether it's Pomele, we actually are working"
#   },
#   {
#     "start": 190.188,
#     "end": 190.528,
#     "speaker": "Speaker_25",
#     "text": "with"
#   },
#   {
#     "start": 190.528,
#     "end": 196.538,
#     "speaker": "Speaker_19",
#     "text": "marketing and creative directors. on that product, notebook LM, that came from working with authors,"
#   },
#   {
#     "start": 197.638,
#     "end": 205.038,
#     "speaker": "Speaker_19",
#     "text": "anti -gravity, flow for filmmaker. You can kind of go down the list, right? So I think that would be how we think about it at a high level"
#   },
#   {
#     "start": 205.038,
#     "end": 205.578,
#     "speaker": "Speaker_26",
#     "text": "is more,"
#   },
#   {
#     "start": 206.078,
#     "end": 228.086,
#     "speaker": "Speaker_19",
#     "text": "how do we get this tool in the hands of either a professional who generally becomes way more prolific or these tools are incredible about really lowering the barriers where people can sort of do things they never could before. So you mentioned Lyria and music. I'm terrible at music, but I can kind of make stuff with Liria. And it's not going to win any awards or anything, but it's fun for my friends. I wouldn't be"
#   },
#   {
#     "start": 228.086,
#     "end": 229.706,
#     "speaker": "Speaker_27",
#     "text": "surprised though. No, no, no, no."
#   },
#   {
#     "start": 230.186,
#     "end": 236.066,
#     "speaker": "Speaker_19",
#     "text": "I mean, the other thing I would say though, is with a lot of this stuff, my best advice, you said kind of one line"
#   },
#   {
#     "start": 236.066,
#     "end": 237.906,
#     "speaker": "Speaker_21",
#     "text": "advice, you just got to try it"
#   },
#   {
#     "start": 237.906,
#     "end": 253.494,
#     "speaker": "Speaker_19",
#     "text": "all the time and see kind of where that frontier is. Cause that frontier keeps moving out and it's jagged, right? And so that would be the way I would say is is try it. these tools, see if they fit in your workflow today. In some cases they might, in some cases they won't yet, but that would be the main"
#   },
#   {
#     "start": 253.494,
#     "end": 255.694,
#     "speaker": "Speaker_28",
#     "text": "advice. So basically playing with AI tools,"
#   },
#   {
#     "start": 255.854,
#     "end": 257.654,
#     "speaker": "Speaker_15",
#     "text": "orchestrating them is the biggest I think"
#   },
#   {
#     "start": 257.654,
#     "end": 259.654,
#     "speaker": "Speaker_29",
#     "text": "that's right. And I think the word you just said is"
#   },
#   {
#     "start": 259.654,
#     "end": 261.674,
#     "speaker": "Speaker_19",
#     "text": "very good, which is kind of play. And I think"
#   },
#   {
#     "start": 261.674,
#     "end": 267.194,
#     "speaker": "Speaker_21",
#     "text": "that's how we try to approach a lot of things, whether it's on Gemini or Labs or AI Studio, is kind of this mindset of play."
#   },
#   {
#     "start": 267.614,
#     "end": 269.654,
#     "speaker": "Speaker_19",
#     "text": "And you're kind of figuring out, like, what is this thing"
#   },
#   {
#     "start": 269.654,
#     "end": 275.624,
#     "speaker": "Speaker_21",
#     "text": "good for? You know what I mean? In some cases, you're like, nah, this is bad. And In some g cases, - like, I can't live without this."
#   },
#   {
#     "start": 275.804,
#     "end": 277.684,
#     "speaker": "Speaker_19",
#     "text": "You know, and then you're trying to figure out kind of in between."
#   },
#   {
#     "start": 278.304,
#     "end": 284.304,
#     "speaker": "Speaker_15",
#     "text": "No, that makes a lot of sense. In fact, one other question that comes quite a lot for people is, every time they think about, hey,"
#   },
#   {
#     "start": 284.404,
#     "end": 285.384,
#     "speaker": "Speaker_30",
#     "text": "you have to play"
#   },
#   {
#     "start": 285.384,
#     "end": 324.05,
#     "speaker": "Speaker_15",
#     "text": "with these AI tools and you have to be on top of it. you know, there's a lot of vibe coding that people have been doing, a lot of agent building like Opel has been doing that really well. Gem has the power of building an agent as well. I think Google AI Studio was initially built for developers. Now, I use that quite a lot. Yeah, Yeah. right. wipe code using build and then anti -gravity dropped. So there is this also sentiment, especially for people who can't code. Right. Saying that, hey, if I want to win the AI race, if I want to win in this AI first world, I need to be technical. I need to be a developer. What is your sense on that? How can someone who's not technical as well have the fair shot at winning versus technical people as well? Yeah, it's interesting. What"
#   },
#   {
#     "start": 324.05,
#     "end": 332.07,
#     "speaker": "Speaker_19",
#     "text": "we're seeing right now, folks that are maybe more professionally trained as a software engineer. year, here. they're wielding, you know, five, ten, 15 agents at"
#   },
#   {
#     "start": 332.07,
#     "end": 333.81,
#     "speaker": "Speaker_31",
#     "text": "a time doing incredible things."
#   },
#   {
#     "start": 334.21,
#     "end": 339.75,
#     "speaker": "Speaker_19",
#     "text": "But I think the other part that's happening at the exact same time is sort of the future of software development"
#   },
#   {
#     "start": 339.75,
#     "end": 340.29,
#     "speaker": "Speaker_32",
#     "text": "really"
#   },
#   {
#     "start": 340.29,
#     "end": 356.742,
#     "speaker": "Speaker_19",
#     "text": "democratizing in really interesting ways. And I mean, you talked about AI Studio, one of the most common things happening right now inside Google, people take a screenshot of their product, say Gmail, and you may have a marketing person or UX or a PIA. or anybody on the team that's not"
#   },
#   {
#     "start": 356.742,
#     "end": 359.342,
#     "speaker": "Speaker_21",
#     "text": "quote unquote technical, drop that into AI Studio,"
#   },
#   {
#     "start": 359.982,
#     "end": 389.908,
#     "speaker": "Speaker_19",
#     "text": "start adding features and sort of hacking on it. Absolutely. Now, we're not at a point yet where you can hit a button and that goes to production, but we're not far. And I think what's interesting is thinking about even like how the relationships between the different functions is changing. And at least for us, a lot of our teams, there's this blurring of people who are like, part engineer, part PM, Part part. UX, do you know what I mean? And those people are oftentimes kind of creating the most interesting kind of breakthrough products. I've been seeing"
#   },
#   {
#     "start": 389.908,
#     "end": 392.188,
#     "speaker": "Speaker_15",
#     "text": "my designers kind of shipping products."
#   },
#   {
#     "start": 393.548,
#     "end": 396.688,
#     "speaker": "Speaker_15",
#     "text": "My PM's kind of building products that's going into production."
#   },
#   {
#     "start": 397.988,
#     "end": 398.988,
#     "speaker": "Speaker_33",
#     "text": "Engineers designing."
#   },
#   {
#     "start": 399.968,
#     "end": 404.068,
#     "speaker": "Speaker_15",
#     "text": "It's absolutely insane. It's happening live. It is. It is just"
#   },
#   {
#     "start": 404.068,
#     "end": 405.388,
#     "speaker": "Speaker_19",
#     "text": "kind of unfolding in front of us."
#   },
#   {
#     "start": 406.028,
#     "end": 414.01,
#     "speaker": "Speaker_15",
#     "text": "No, look, I think you guys have been shipping like like this. crazy. The most of the time that I would like to spend going forward is for me to see stuff on how you use the stuff that"
#   },
#   {
#     "start": 414.01,
#     "end": 415.97,
#     "speaker": "Speaker_34",
#     "text": "you build. let's do that. OK,"
#   },
#   {
#     "start": 416.09,
#     "end": 442.048,
#     "speaker": "Speaker_19",
#     "text": "that sounds good. we can maybe cut to the demo here. Let's I thought we could maybe just start. You've been on this site, and I'm sure a lot of your listeners have too. But this is the Google Lab site. As far as I know, it's the only Google site with a hot pink banner at the top. But it's kind of all our stuff. So you know, pomel, CC, Mixed the export, Bull. Opal, you can kind of go through and kind of check it all out. Absolutely. And anyways, everybody can check that out. It's really fun. But maybe what I thought you could start"
#   },
#   {
#     "start": 442.048,
#     "end": 443.968,
#     "speaker": "Speaker_35",
#     "text": "with is Pomele. I don't know if you'll notice"
#   },
#   {
#     "start": 443.968,
#     "end": 447.948,
#     "speaker": "Speaker_15",
#     "text": "this. Internet has been filled with videos about Pomele. It has. People"
#   },
#   {
#     "start": 447.948,
#     "end": 449.548,
#     "speaker": "Speaker_36",
#     "text": "have been loving it. Yeah,"
#   },
#   {
#     "start": 449.808,
#     "end": 453.628,
#     "speaker": "Speaker_19",
#     "text": "fun fact, the Pomele tweet, number one Google labs tweet in history."
#   },
#   {
#     "start": 453.908,
#     "end": 455.968,
#     "speaker": "Speaker_37",
#     "text": "Insane. Number four tweet in Google's"
#   },
#   {
#     "start": 455.968,
#     "end": 457.808,
#     "speaker": "Speaker_19",
#     "text": "history. Wow. So it really took off."
#   },
#   {
#     "start": 458.428,
#     "end": 460.04,
#     "speaker": "Speaker_38",
#     "text": "But did you guys think of it as as"
#   },
#   {
#     "start": 460.008,
#     "end": 465.9,
#     "speaker": "Speaker_15",
#     "text": "you guys are building it. Because I also wanted to understand how you guys think about labs projects and how do you run the team as well. But you get"
#   },
#   {
#     "start": 465.9,
#     "end": 468.14,
#     "speaker": "Speaker_37",
#     "text": "to it slightly. Yeah, maybe Pimeli's an interesting example. So"
#   },
#   {
#     "start": 468.14,
#     "end": 493.844,
#     "speaker": "Speaker_19",
#     "text": "we can do the demo. It's like as you're starting on something like this, we're very interested in how hard it is for small businesses to create marketing assets. Very true. And collateral and all the social stuff and everything. So it kind of started with a deceptively simple idea. And it was an experiment. was basically like, like I'll show you. you this next tab. is an organization in my hometown in Oklahoma City, OKC, called Restore OKC. And the idea was, could you"
#   },
#   {
#     "start": 493.844,
#     "end": 495.024,
#     "speaker": "Speaker_21",
#     "text": "just take the URL,"
#   },
#   {
#     "start": 496.224,
#     "end": 501.364,
#     "speaker": "Speaker_19",
#     "text": "restoreokc.org, and drop it into a tool, hit a button, and start getting creative assets."
#   },
#   {
#     "start": 501.784,
#     "end": 503.564,
#     "speaker": "Speaker_15",
#     "text": "That's where it started. Can a tool be a marketing team?"
#   },
#   {
#     "start": 503.884,
#     "end": 542.6,
#     "speaker": "Speaker_19",
#     "text": "Well, we didn't even start there. We basically were like, can you even just extract interesting things? So here's what you do. You drop the tool in, and you get this thing called your business. business DNA. And you can see what there's the URL. Here's the font. Here's the color palette. Here's some of the assets from the website. And we're like, okay, that's kind of interesting because it's like one little step. You get all this value. And then we're like, okay, what if you could make campaigns out of this? And it just starts creating again, you look at all this stuff, you're going to have like the font, the sort of sort of assets, it kind of fits this organization actually does a lot of kind of food service and donations do - in the community. And then a few weeks ago, we dropped this feature called"
#   },
#   {
#     "start": 542.6,
#     "end": 543.2,
#     "speaker": "Speaker_39",
#     "text": "Photo Shoot."
#   },
#   {
#     "start": 543.62,
#     "end": 545.74,
#     "speaker": "Speaker_19",
#     "text": "And this was the one that really popped."
#   },
#   {
#     "start": 546.68,
#     "end": 547.46,
#     "speaker": "Speaker_40",
#     "text": "it's all over the internet."
#   },
#   {
#     "start": 548.1,
#     "end": 573.424,
#     "speaker": "Speaker_19",
#     "text": "And the idea here was like, can you take assets from your sort of website, in this case, select an image. Here's all the assets off the web page. Let's pick this head of lettuce or something like this. And you can say, yeah, it looks good. And then basically what you can just kind of put these and temple it. So I just kind of zoomed ahead head here. here so you can see it. But now it's like, here's your piece of lettuce on all these interesting backgrounds. And all this stuff you can download and take it wherever you want, right?"
#   },
#   {
#     "start": 573.904,
#     "end": 575.064,
#     "speaker": "Speaker_21",
#     "text": "And that's kind of how"
#   },
#   {
#     "start": 575.064,
#     "end": 578.984,
#     "speaker": "Speaker_19",
#     "text": "this thing gets started. And now people are starting to use it like crazy."
#   },
#   {
#     "start": 580.424,
#     "end": 584.824,
#     "speaker": "Speaker_19",
#     "text": "Everywhere. launched in 160 countries, so it's now spread out. India launch was"
#   },
#   {
#     "start": 584.824,
#     "end": 586.864,
#     "speaker": "Speaker_41",
#     "text": "wide. Yeah, it was."
#   },
#   {
#     "start": 587.104,
#     "end": 589.064,
#     "speaker": "Speaker_19",
#     "text": "I agree. We were watching the dashboards"
#   },
#   {
#     "start": 589.064,
#     "end": 590.584,
#     "speaker": "Speaker_42",
#     "text": "of the TPUs very closely."
#   },
#   {
#     "start": 591.584,
#     "end": 654.556,
#     "speaker": "Speaker_19",
#     "text": "But this is an example of how something Your starts again we're co -creating it with marketing people yeah we think of it as a tool we don't think of it as replacing people because this is actually something a lot of small businesses don't have access to photography like this or the time or the setup so it kind of creates this ability to kind of give someone sort of superpower in this case so that's one example another one is kind of interesting on the design side is a project called stitch I love it yeah yeah Yeah, yeah, cool. So this one's fun. The idea behind this is what if you could kind of describe kind of an interface you wanted? And you can see here it could be an app or a website. I kind of was working on one earlier. This is like a discover Oklahoma City again back to my hometown. you can see it's kind of an infinite canvas kind of idea. Nice little touch by the way design. See the little smile like that traces. Okay, so here's how it works. You're kind of in this thing and you can go in and literally just come in and edit these things, drag it around, you can describe sort of changes you want to make, and then we just added this feature recently which is sweet. Right click on this thing and make an instant"
#   },
#   {
#     "start": 654.556,
#     "end": 655.076,
#     "speaker": "Speaker_43",
#     "text": "prototype."
#   },
#   {
#     "start": 655.836,
#     "end": 681.818,
#     "speaker": "Speaker_19",
#     "text": "Now you see this arrow just got added, that stitch almost like the AI's in the board with you starting to make things. It's going to go off and use the Gemini 3 model. Here it comes to turn this thing into actually a clickable prototype. So if I click in here, boom, here's like your trip plan, you can go back, you can go to some of your saved places. So again, this whole thing, what's also so cool about this is any of these screens, you can right"
#   },
#   {
#     "start": 681.818,
#     "end": 683.358,
#     "speaker": "Speaker_21",
#     "text": "click and just grab the code."
#   },
#   {
#     "start": 684.258,
#     "end": 688.438,
#     "speaker": "Speaker_19",
#     "text": "And it'll pull this up and you've got all the front end code ready to go. So while Stitch"
#   },
#   {
#     "start": 688.438,
#     "end": 692.178,
#     "speaker": "Speaker_15",
#     "text": "is actually a design first tool, it's in a way being built"
#   },
#   {
#     "start": 692.178,
#     "end": 693.518,
#     "speaker": "Speaker_44",
#     "text": "using code. Exactly."
#   },
#   {
#     "start": 694.118,
#     "end": 698.33,
#     "speaker": "Speaker_15",
#     "text": "So it's vibe coding, but with a vibe design interface. It's like an inception. exception"
#   },
#   {
#     "start": 698.33,
#     "end": 700.61,
#     "speaker": "Speaker_45",
#     "text": "thing here. Yeah, and"
#   },
#   {
#     "start": 700.61,
#     "end": 703.73,
#     "speaker": "Speaker_21",
#     "text": "I think what people are finding here, you mentioned this earlier, it's like,"
#   },
#   {
#     "start": 704.29,
#     "end": 705.37,
#     "speaker": "Speaker_46",
#     "text": "who's using Stitch?"
#   },
#   {
#     "start": 706.25,
#     "end": 708.37,
#     "speaker": "Speaker_19",
#     "text": "This is a whole category we think of vibe design."
#   },
#   {
#     "start": 709.19,
#     "end": 723.25,
#     "speaker": "Speaker_21",
#     "text": "People that are using it are not, designers are using it, but you also have an engineer. who never could have maybe done front end codes, back end engineer that comes to it. You're having people take this into AI studio and then start doing things. So you're getting all these really"
#   },
#   {
#     "start": 723.25,
#     "end": 725.222,
#     "speaker": "Speaker_47",
#     "text": "interesting combinations. Now you can do that to"
#   },
#   {
#     "start": 725.222,
#     "end": 725.802,
#     "speaker": "Speaker_15",
#     "text": "antigravity anti"
#   },
#   {
#     "start": 725.39,
#     "end": 725.39,
#     "speaker": "Speaker_47",
#     "text": "-"
#   },
#   {
#     "start": 725.802,
#     "end": 727.162,
#     "speaker": "Speaker_15",
#     "text": "as well. That's right, that's right."
#   },
#   {
#     "start": 727.202,
#     "end": 727.342,
#     "speaker": "Speaker_21",
#     "text": "Yeah,"
#   },
#   {
#     "start": 727.502,
#     "end": 727.502,
#     "speaker": "Speaker_15",
#     "text": "yeah, yeah."
#   },
#   {
#     "start": 727.982,
#     "end": 729.182,
#     "speaker": "Speaker_21",
#     "text": "That's right, you can drop it in there too."
#   },
#   {
#     "start": 729.762,
#     "end": 737.322,
#     "speaker": "Speaker_19",
#     "text": "So this is kind of where Stitch is right now, kind of where it's going, it's kind of interesting. Maybe I'll just keep going, is that okay? please have lot of tabs lined up"
#   },
#   {
#     "start": 737.322,
#     "end": 737.342,
#     "speaker": "Speaker_48",
#     "text": "for"
#   },
#   {
#     "start": 737.342,
#     "end": 737.342,
#     "speaker": "Speaker_19",
#     "text": "you."
#   },
#   {
#     "start": 737.342,
#     "end": 739.122,
#     "speaker": "Speaker_48",
#     "text": "Yeah, let's go for it, let's go for it. So"
#   },
#   {
#     "start": 739.122,
#     "end": 760.42,
#     "speaker": "Speaker_19",
#     "text": "this is, this is no book L.M. This is one of our first Google Labs products that sort of went viral with the podcast. I think the things that I'm very excited about where this is going next, so we've added obviously the the ability to do deep research right in notebook L.M. here's like a trip, like planning a trip to Hawaii. You can do deep research and grab 66 sources."
#   },
#   {
#     "start": 761.48,
#     "end": 779.292,
#     "speaker": "Speaker_19",
#     "text": "And of course you can do your normal Q and A with it, but there's some new things that have come out that are pretty fun. So one is, I'm sure people have seen the infographics. One tap, this is pretty cool because Hawaii obviously several different islands. I love these little snapshots of each island that you can kind of check out. out so that's kind of fun. The newest thing"
#   },
#   {
#     "start": 779.292,
#     "end": 780.932,
#     "speaker": "Speaker_21",
#     "text": "though is actually these"
#   },
#   {
#     "start": 780.932,
#     "end": 793.012,
#     "speaker": "Speaker_19",
#     "text": "cinematic video overviews. So what's really cool before I play it is imagine 66 sources in this case. Gemini is going to basically act as kind of an assistant director,"
#   },
#   {
#     "start": 793.652,
#     "end": 805.898,
#     "speaker": "Speaker_21",
#     "text": "put together a script with kind of like drama and plot and everything. It's going to come up with a visual style which you can customize if you want and then put it all to kind of audio and time it all up. So do you want to see a"
#   },
#   {
#     "start": 805.898,
#     "end": 807.358,
#     "speaker": "Speaker_49",
#     "text": "little of that? please. Let's do it."
#   },
#   {
#     "start": 807.598,
#     "end": 813.718,
#     "speaker": "Speaker_21",
#     "text": "Put a little audio on here and I'll make it bigger. Now this is pretty cool. This was like a felt style it just came up with. This is the"
#   },
#   {
#     "start": 813.718,
#     "end": 815.698,
#     "speaker": "Speaker_50",
#     "text": "ocean, check this When you picture a trip to"
#   },
#   {
#     "start": 815.698,
#     "end": 817.778,
#     "speaker": "Speaker_51",
#     "text": "Hawaii, you probably imagine this,"
#   },
#   {
#     "start": 818.418,
#     "end": 821.638,
#     "speaker": "Speaker_52",
#     "text": "empty white sand beaches, perfect surf, and"
#   },
#   {
#     "start": 821.638,
#     "end": 823.558,
#     "speaker": "Speaker_53",
#     "text": "total isolation from daily stress."
#   },
#   {
#     "start": 824.298,
#     "end": 826.418,
#     "speaker": "Speaker_51",
#     "text": "This equation shows the financial reality"
#   },
#   {
#     "start": 826.418,
#     "end": 827.178,
#     "speaker": "Speaker_54",
#     "text": "of that dream,"
#   },
#   {
#     "start": 827.818,
#     "end": 829.938,
#     "speaker": "Speaker_53",
#     "text": "a standard seven day trip for two people."
#   },
#   {
#     "start": 830.202,
#     "end": 832.102,
#     "speaker": "Speaker_51",
#     "text": "factoring in place, launching."
#   },
#   {
#     "start": 832.462,
#     "end": 844.502,
#     "speaker": "Speaker_21",
#     "text": "Now I'm going to pause for just a second because all of these are actually coded in the background. So Gemini is like, I should make an interactive chart that builds this bar chart, writes the code and then drops it in, which is kind"
#   },
#   {
#     "start": 844.502,
#     "end": 846.182,
#     "speaker": "Speaker_55",
#     "text": "of a cool... So it's basically"
#   },
#   {
#     "start": 846.182,
#     "end": 852.462,
#     "speaker": "Speaker_15",
#     "text": "converting an animation into a video. That's it. And the animation is... So the beauty of this world is everything is written"
#   },
#   {
#     "start": 852.462,
#     "end": 853.522,
#     "speaker": "Speaker_56",
#     "text": "using code. There you go."
#   },
#   {
#     "start": 853.942,
#     "end": 859.902,
#     "speaker": "Speaker_21",
#     "text": "Wow. So as we go through it, we won't play the whole thing but I want to play you one more little section sec... but this I wanted to call out just because"
#   },
#   {
#     "start": 859.902,
#     "end": 862.122,
#     "speaker": "Speaker_57",
#     "text": "I thought you'd like that. Okay"
#   },
#   {
#     "start": 862.122,
#     "end": 863.322,
#     "speaker": "Speaker_21",
#     "text": "so is an expensive trip."
#   },
#   {
#     "start": 864.582,
#     "end": 865.882,
#     "speaker": "Speaker_58",
#     "text": "I'm sure you're gonna fart it."
#   },
#   {
#     "start": 867.462,
#     "end": 867.942,
#     "speaker": "Speaker_59",
#     "text": "Now"
#   },
#   {
#     "start": 867.942,
#     "end": 869.802,
#     "speaker": "Speaker_19",
#     "text": "check this out because then it's gonna"
#   },
#   {
#     "start": 869.802,
#     "end": 881.622,
#     "speaker": "Speaker_51",
#     "text": "go through. Blur the Hawaiian islands together into one identical flawless paradise. Behind those filtered photos each of the four main islands features radically different weather patterns. Okay"
#   },
#   {
#     "start": 881.622,
#     "end": 883.622,
#     "speaker": "Speaker_19",
#     "text": "so here's another example we take like a map."
#   },
#   {
#     "start": 884.25,
#     "end": 888.31,
#     "speaker": "Speaker_21",
#     "text": "Convert it to code and kind of do this overlay and start connecting it this way So"
#   },
#   {
#     "start": 888.31,
#     "end": 896.45,
#     "speaker": "Speaker_19",
#     "text": "when we saw I remember the first time I saw this I was like whoa, this is new But it's kind of again this blurring and mixing of in this"
#   },
#   {
#     "start": 896.45,
#     "end": 897.43,
#     "speaker": "Speaker_21",
#     "text": "case some code"
#   },
#   {
#     "start": 897.43,
#     "end": 903.91,
#     "speaker": "Speaker_19",
#     "text": "some video some nano banana all coming together And I think what's amazing and kind of what's made notebooks such"
#   },
#   {
#     "start": 903.91,
#     "end": 907.97,
#     "speaker": "Speaker_21",
#     "text": "a fun project is just he helps you understand anything So"
#   },
#   {
#     "start": 907.97,
#     "end": 915.87,
#     "speaker": "Speaker_19",
#     "text": "whether it's planning a trip or you're a student or you're a teacher or you're a knowledge worker work or whatever, you just drop in the sources and then you can start making stuff with"
#   },
#   {
#     "start": 915.87,
#     "end": 921.49,
#     "speaker": "Speaker_15",
#     "text": "it. I think this is a perfect tool for people when they say that every person can have an AI tutor."
#   },
#   {
#     "start": 921.83,
#     "end": 922.79,
#     "speaker": "Speaker_60",
#     "text": "Yes. I think this is it."
#   },
#   {
#     "start": 923.21,
#     "end": 927.23,
#     "speaker": "Speaker_19",
#     "text": "That's how a lot of people are using it. That's exactly right. Yeah, quizzes in this thing are super popular."
#   },
#   {
#     "start": 927.55,
#     "end": 945.454,
#     "speaker": "Speaker_15",
#     "text": "And so is the podcast. I will tell you how I use this, right? yeah. I'm geeking on AI and every single day I wake up with 100 updates. Yeah. So if I have found a way to ingest ingest all the updates into this, it converts that into a podcast and when I'm in the gym, I'm listening to the notebook L.M. podcast. Nice. Right? Now, I have a"
#   },
#   {
#     "start": 945.454,
#     "end": 947.654,
#     "speaker": "Speaker_61",
#     "text": "request for you. Okay. You guys"
#   },
#   {
#     "start": 947.654,
#     "end": 948.314,
#     "speaker": "Speaker_62",
#     "text": "shipped"
#   },
#   {
#     "start": 948.314,
#     "end": 952.674,
#     "speaker": "Speaker_15",
#     "text": "the CLI for Google Workspace. Can you please add notebook L.M. to that"
#   },
#   {
#     "start": 952.674,
#     "end": 954.594,
#     "speaker": "Speaker_63",
#     "text": "as well? So that I can automate"
#   },
#   {
#     "start": 954.594,
#     "end": 956.774,
#     "speaker": "Speaker_64",
#     "text": "it. One of the top requests either CLI"
#   },
#   {
#     "start": 956.774,
#     "end": 958.454,
#     "speaker": "Speaker_65",
#     "text": "or MCP for notebooks. Please do."
#   },
#   {
#     "start": 958.694,
#     "end": 960.774,
#     "speaker": "Speaker_14",
#     "text": "Okay, feature request noted. Now, people have"
#   },
#   {
#     "start": 960.774,
#     "end": 964.654,
#     "speaker": "Speaker_15",
#     "text": "been hacking this round. I actually do it by the way today by using browser use."
#   },
#   {
#     "start": 964.506,
#     "end": 966.586,
#     "speaker": "Speaker_66",
#     "text": "Yeah, yeah, right, but I'm like,"
#   },
#   {
#     "start": 966.666,
#     "end": 968.626,
#     "speaker": "Speaker_67",
#     "text": "yeah, can you please make it in the air for"
#   },
#   {
#     "start": 968.626,
#     "end": 970.386,
#     "speaker": "Speaker_68",
#     "text": "me please? Okay, noted,"
#   },
#   {
#     "start": 970.586,
#     "end": 982.626,
#     "speaker": "Speaker_19",
#     "text": "noted. Okay, two more for you. That's okay, let's do a little genie and then we can jump over to Gemini. So, genie I think is one of those projects where you kind of have to see it to believe it. And I remember exactly where I was"
#   },
#   {
#     "start": 982.626,
#     "end": 984.146,
#     "speaker": "Speaker_21",
#     "text": "when I saw the first one, I was just like,"
#   },
#   {
#     "start": 984.566,
#     "end": 984.846,
#     "speaker": "Speaker_69",
#     "text": "what?"
#   },
#   {
#     "start": 985.946,
#     "end": 986.526,
#     "speaker": "Speaker_69",
#     "text": "I can't believe is possible. this What"
#   },
#   {
#     "start": 986.526,
#     "end": 987.406,
#     "speaker": "Speaker_70",
#     "text": "did we just made?"
#   },
#   {
#     "start": 988.686,
#     "end": 1026.51,
#     "speaker": "Speaker_19",
#     "text": "So, you know, the thing about Genie genie, is kind of a world -building kind of tool. It's very experimental right now. It's very limited in terms of even just how many people we can have on it. What's kind of fun is we built all these little worlds I love the cat one. You can try. The cat one's kind of fun, right? Yeah. Yeah I think the other thing that's kind of fun about Genie is you can bring your own, right? Yeah, so that's pretty fun too. This one's kind of one of my new favorites I've been using this one recently. This is like, you know, kind of a parrot or or whatever whatever flying through the Amazon. Now as this world gets built, it takes about 20, 25 seconds. You'll see the keys coming on here. It's kind of old school gaming, space bar to jump, you"
#   },
#   {
#     "start": 1026.51,
#     "end": 1028.53,
#     "speaker": "Speaker_71",
#     "text": "know, WASD to turn, you can"
#   },
#   {
#     "start": 1028.53,
#     "end": 1030.53,
#     "speaker": "Speaker_72",
#     "text": "change the camera angle. The GDA vice city is"
#   },
#   {
#     "start": 1030.53,
#     "end": 1032.07,
#     "speaker": "Speaker_73",
#     "text": "bad. That's right, that's right."
#   },
#   {
#     "start": 1032.45,
#     "end": 1042.33,
#     "speaker": "Speaker_19",
#     "text": "And I think what's been fun is just watching because at the end of this, it'll record it and you can share the video. so there's a whole other kind of side of Genie which are people sharing these worlds. I've tried to put"
#   },
#   {
#     "start": 1042.33,
#     "end": 1044.388,
#     "speaker": "Speaker_15",
#     "text": "my... myself in one of these scenes as well. Oh"
#   },
#   {
#     "start": 1044.388,
#     "end": 1046.568,
#     "speaker": "Speaker_74",
#     "text": "nice, is it any good? It was pretty"
#   },
#   {
#     "start": 1046.568,
#     "end": 1048.388,
#     "speaker": "Speaker_15",
#     "text": "good actually. It's better than what I expected. Okay,"
#   },
#   {
#     "start": 1048.468,
#     "end": 1052.448,
#     "speaker": "Speaker_21",
#     "text": "so here's our bird. He's, oh wow, he's flying pretty fast. we're gonna try to make it"
#   },
#   {
#     "start": 1052.448,
#     "end": 1054.448,
#     "speaker": "Speaker_22",
#     "text": "through this tunnel. I think, yeah, there we go."
#   },
#   {
#     "start": 1054.488,
#     "end": 1056.308,
#     "speaker": "Speaker_21",
#     "text": "Now we're on the other side and I'll hit space bar and I'm gonna"
#   },
#   {
#     "start": 1056.308,
#     "end": 1058.808,
#     "speaker": "Speaker_19",
#     "text": "start climbing, try to get to the top of this,"
#   },
#   {
#     "start": 1059.308,
#     "end": 1061.568,
#     "speaker": "Speaker_75",
#     "text": "whatever, a little room here. There's like a balinese"
#   },
#   {
#     "start": 1061.568,
#     "end": 1063.288,
#     "speaker": "Speaker_76",
#     "text": "- Check the shadow, see the shadow"
#   },
#   {
#     "start": 1063.288,
#     "end": 1065.208,
#     "speaker": "Speaker_21",
#     "text": "right over there. It's incredible. Yeah, it looks like"
#   },
#   {
#     "start": 1065.208,
#     "end": 1067.248,
#     "speaker": "Speaker_19",
#     "text": "we're somewhere, like Angkor Wat or"
#   },
#   {
#     "start": 1067.248,
#     "end": 1071.35,
#     "speaker": "Speaker_21",
#     "text": "something, right? Now I think what's What's amazing amazing state tomorrow as the about this is every frame is"
#   },
#   {
#     "start": 1071.35,
#     "end": 1073.33,
#     "speaker": "Speaker_77",
#     "text": "being generated. On the fly. On the fly. So,"
#   },
#   {
#     "start": 1073.77,
#     "end": 1078.91,
#     "speaker": "Speaker_21",
#     "text": "it's insane. When I turn this, I'm going to kind of steer him a little bit. That jungle's there. If we came back and flew through"
#   },
#   {
#     "start": 1078.91,
#     "end": 1080.85,
#     "speaker": "Speaker_19",
#     "text": "this again, that jungle may not be there."
#   },
#   {
#     "start": 1081.47,
#     "end": 1082.99,
#     "speaker": "Speaker_78",
#     "text": "So it's not kept or got it. It's all"
#   },
#   {
#     "start": 1082.99,
#     "end": 1093.21,
#     "speaker": "Speaker_21",
#     "text": "generated in sort of truly in the generative sense. Every pixel is kind of streamed in this way. Now the other thing you'll notice, which is kind of fun, you see at the top there's this bar that's getting dangerously close to the end."
#   },
#   {
#     "start": 1093.21,
#     "end": 1095.398,
#     "speaker": "Speaker_19",
#     "text": "This, our world is about to collapse. collapse."
#   },
#   {
#     "start": 1095.778,
#     "end": 1097.338,
#     "speaker": "Speaker_79",
#     "text": "So right now the genie"
#   },
#   {
#     "start": 1097.338,
#     "end": 1111.158,
#     "speaker": "Speaker_21",
#     "text": "world only lasts 60 seconds and then they're gone. So what'll happen is it gets to the end here. Oh, I've never actually seen this little river back here. This is interesting. Okay. See how he just froze? Yeah. And now our world's like collapsing on us. We do that partly. could keep the consistency."
#   },
#   {
#     "start": 1111.498,
#     "end": 1115.198,
#     "speaker": "Speaker_19",
#     "text": "That's about as long as it'll last partly cause we don't want to melt too many. Yeah. That's, that's what"
#   },
#   {
#     "start": 1115.198,
#     "end": 1117.058,
#     "speaker": "Speaker_80",
#     "text": "I was thinking. don't want to measure your genie. That's right."
#   },
#   {
#     "start": 1117.278,
#     "end": 1128.836,
#     "speaker": "Speaker_19",
#     "text": "That's right. That's right. So anyway, this is, um, genie. We're super excited because because clearly this is a little bit of a toy right now in terms of the experiment we've built, but it shows kind of the potential we think of"
#   },
#   {
#     "start": 1128.836,
#     "end": 1129.516,
#     "speaker": "Speaker_81",
#     "text": "gaming,"
#   },
#   {
#     "start": 1130.076,
#     "end": 1140.216,
#     "speaker": "Speaker_19",
#     "text": "the potential maybe of entertainment, potential even of robotics and embodied AI, because as you're building these worlds, you're getting a feel for how to navigate them. So we'll see you a lot more from this in the coming"
#   },
#   {
#     "start": 1140.216,
#     "end": 1142.216,
#     "speaker": "Speaker_15",
#     "text": "years. The first thing that came to my mind when I saw Jeannie"
#   },
#   {
#     "start": 1142.216,
#     "end": 1143.556,
#     "speaker": "Speaker_82",
#     "text": "is I"
#   },
#   {
#     "start": 1143.556,
#     "end": 1145.456,
#     "speaker": "Speaker_15",
#     "text": "miss my old hometown, the way it"
#   },
#   {
#     "start": 1145.456,
#     "end": 1147.096,
#     "speaker": "Speaker_83",
#     "text": "looked. Oh yeah. Right?"
#   },
#   {
#     "start": 1147.258,
#     "end": 1153.598,
#     "speaker": "Speaker_15",
#     "text": "And I believe tech like this will enable me to preserve the place the way it is on a 3D view."
#   },
#   {
#     "start": 1153.998,
#     "end": 1155.578,
#     "speaker": "Speaker_84",
#     "text": "And then I could actually go back."
#   },
#   {
#     "start": 1155.778,
#     "end": 1157.578,
#     "speaker": "Speaker_85",
#     "text": "Yeah, yeah, yeah. Right? So it's"
#   },
#   {
#     "start": 1157.578,
#     "end": 1163.698,
#     "speaker": "Speaker_15",
#     "text": "like Google Earth. But 10 years behind, 15 years behind. And I preserve that forever. For my kids to see, for my"
#   },
#   {
#     "start": 1163.698,
#     "end": 1165.218,
#     "speaker": "Speaker_86",
#     "text": "grandkids to see. Yeah, yeah."
#   },
#   {
#     "start": 1165.598,
#     "end": 1167.558,
#     "speaker": "Speaker_87",
#     "text": "Sort of captured in that world. Yes. So I can"
#   },
#   {
#     "start": 1167.558,
#     "end": 1171.618,
#     "speaker": "Speaker_15",
#     "text": "see a product, I'm sure you guys are thinking about it. A mix of Genie plus"
#   },
#   {
#     "start": 1171.618,
#     "end": 1173.602,
#     "speaker": "Speaker_88",
#     "text": "Google Earth. Yes, yeah. Right? We know"
#   },
#   {
#     "start": 1173.602,
#     "end": 1189.742,
#     "speaker": "Speaker_19",
#     "text": "it's so funny, back in California, in Mountain View, there used to be this big Google Earth display. You'd walk in, it was wraparound screens. You had a little joystick. Guess what the number one thing everyone would do? They'd go to their home town. it. And they would kind of zoom in. was satellite view."
#   },
#   {
#     "start": 1189.822,
#     "end": 1193.542,
#     "speaker": "Speaker_15",
#     "text": "I had done that too. I mean, the first time when I came across Google Earth, I'd be"
#   },
#   {
#     "start": 1193.542,
#     "end": 1195.202,
#     "speaker": "Speaker_89",
#     "text": "like, can I find my home? And I did."
#   },
#   {
#     "start": 1196.122,
#     "end": 1197.502,
#     "speaker": "Speaker_90",
#     "text": "yeah. Yeah, but this is"
#   },
#   {
#     "start": 1197.502,
#     "end": 1201.448,
#     "speaker": "Speaker_19",
#     "text": "cool because you could actually walk the streets. or I don't know become a parrot and fly"
#   },
#   {
#     "start": 1201.448,
#     "end": 1203.588,
#     "speaker": "Speaker_91",
#     "text": "around or something. you guys should have shipped this four or five"
#   },
#   {
#     "start": 1203.588,
#     "end": 1205.468,
#     "speaker": "Speaker_15",
#     "text": "years before so that GTFI could have made it"
#   },
#   {
#     "start": 1205.468,
#     "end": 1208.588,
#     "speaker": "Speaker_92",
#     "text": "earlier. man,"
#   },
#   {
#     "start": 1208.768,
#     "end": 1209.668,
#     "speaker": "Speaker_93",
#     "text": "I don't know, that's"
#   },
#   {
#     "start": 1209.668,
#     "end": 1213.708,
#     "speaker": "Speaker_15",
#     "text": "a different thing. No but we have done vibe design, we have done vibe code. Yeah. Now we are"
#   },
#   {
#     "start": 1213.708,
#     "end": 1215.748,
#     "speaker": "Speaker_94",
#     "text": "basically vibe gaming. Yeah, we've got world"
#   },
#   {
#     "start": 1215.748,
#     "end": 1217.728,
#     "speaker": "Speaker_95",
#     "text": "-building happening. This is God"
#   },
#   {
#     "start": 1217.728,
#     "end": 1219.728,
#     "speaker": "Speaker_96",
#     "text": "mode. Let me show you one last"
#   },
#   {
#     "start": 1219.728,
#     "end": 1244.864,
#     "speaker": "Speaker_19",
#     "text": "bit on just Gemini. We can rap here I guess. So I think nano banana obviously. Thank Thank you. you to India. was one of the first countries where it took off. It was just unbelievable. I would say I'll show you some various things. But I mean, one thing with Nanobanana 2 is obviously the text renderer. Text, yes. Just sets it apart. This is really fun. Viral trend is like gnolling things, separating it out into the component parts."
#   },
#   {
#     "start": 1245.944,
#     "end": 1253.416,
#     "speaker": "Speaker_19",
#     "text": "But this has just become a thing. I think we'll see Nanobanana -type experiences for video video. for music, for voice,"
#   },
#   {
#     "start": 1253.656,
#     "end": 1254.656,
#     "speaker": "Speaker_21",
#     "text": "like this idea to just"
#   },
#   {
#     "start": 1254.656,
#     "end": 1258.936,
#     "speaker": "Speaker_19",
#     "text": "conversationally edit. It feels so natural, right? It's how it should work."
#   },
#   {
#     "start": 1259.876,
#     "end": 1261.016,
#     "speaker": "Speaker_15",
#     "text": "It's like talking to a designer,"
#   },
#   {
#     "start": 1261.336,
#     "end": 1263.136,
#     "speaker": "Speaker_97",
#     "text": "right next to you. Yeah, that's right."
#   },
#   {
#     "start": 1263.276,
#     "end": 1277.096,
#     "speaker": "Speaker_19",
#     "text": "And being able to kind of iterate on things goes back to some of the things we said about control and sort of that precision. So anyway, we're really excited about all the nano -banana growth and other usage. This one's kind of fun. You know, I threw in something, congrats on the T20, by the way."
#   },
#   {
#     "start": 1277.256,
#     "end": 1279.024,
#     "speaker": "Speaker_98",
#     "text": "Hey, yes. when we were You're"
#   },
#   {
#     "start": 1279.016,
#     "end": 1299.184,
#     "speaker": "Speaker_19",
#     "text": "filming. filming this, I guess. But you can take something in Gemini now and just kind of create music very easily. And actually, maybe I'll just show you real quick how that comes up. It's super easy, because you just drop into Gemini and just say, like, create music. And you've got all these templates to choose from, right? And so here's one. One of my favorite ones is this thing called"
#   },
#   {
#     "start": 1299.184,
#     "end": 1299.784,
#     "speaker": "Speaker_99",
#     "text": "Bad Music."
#   },
#   {
#     "start": 1300.544,
#     "end": 1302.164,
#     "speaker": "Speaker_100",
#     "text": "Bad Music. So you could throw"
#   },
#   {
#     "start": 1302.164,
#     "end": 1309.298,
#     "speaker": "Speaker_21",
#     "text": "in something simple, like India Champions T20, runs. runs, and then it'll just come back with something like this."
#   },
#   {
#     "start": 1312.058,
#     "end": 1314.298,
#     "speaker": "Speaker_101",
#     "text": "Titans, the thunder of victory, the trajectory"
#   },
#   {
# ...
#     "text": "But this starts to show the examples of like, how powerful it is if you wanna connect this stuff. And it's we see Gemini being this personal, proactive, powerful assistant that's working"
#   },
#   {
#     "start": 1462.484,
#     "end": 1462.984,
#     "speaker": "Speaker_108",
#     "text": "for you."
#   },
#   {
#     "start": 1463.444,
#     "end": 1511.748,
#     "speaker": "Speaker_19",
#     "text": "And in this case, I was like, I would have just looked through my email or my gallery forever to find me. for It's so hard to find these kind of things. So it's like instant retrieval. The other thing we're finding people are using it a lot for. I'll show you this kind of fun was, remind me about my past visits to India before this trip. And so here it is, like here's when you were in Delhi, Bangalore, Mumbai, Hyderabad, you went to Mathura and Jaipur. sweet. And then what's kind of fun is like, oh show me my photos from Jaipur. It's like, bam, there it is. So it's kind of this incredible, ability with personal intelligence to really make AI yours. And I think that's kind of the promise we see with something like this. So this is in the US today and rolling out very soon. The feedback on this has been very positive. So we're really excited to get this"
#   },
#   {
#     "start": 1511.748,
#     "end": 1513.488,
#     "speaker": "Speaker_109",
#     "text": "out. How far are we Josh"
#   },
#   {
#     "start": 1513.488,
#     "end": 1524.918,
#     "speaker": "Speaker_15",
#     "text": "from AI literally recommending our stuff proactively rather than us prompting it? For example, here you're talking about prescription. Yeah, that's because this has to be prompted and I think you do not know."
#   },
#   {
#     "start": 1525.198,
#     "end": 1526.778,
#     "speaker": "Speaker_110",
#     "text": "But it could be a bunch of things. It"
#   },
#   {
#     "start": 1526.778,
#     "end": 1531.038,
#     "speaker": "Speaker_15",
#     "text": "could be proactive, for example. You have a flight, and you haven't booked"
#   },
#   {
#     "start": 1531.038,
#     "end": 1532.598,
#     "speaker": "Speaker_111",
#     "text": "your seat. Yeah,"
#   },
#   {
#     "start": 1532.898,
#     "end": 1534.818,
#     "speaker": "Speaker_112",
#     "text": "yeah, How far would it the car, like"
#   },
#   {
#     "start": 1534.818,
#     "end": 1538.338,
#     "speaker": "Speaker_21",
#     "text": "a taxi on the other side, whatever, rental car, whatever. You're reading the roadmap."
#   },
#   {
#     "start": 1538.838,
#     "end": 1540.858,
#     "speaker": "Speaker_22",
#     "text": "Yeah? Okay, okay. Part"
#   },
#   {
#     "start": 1540.858,
#     "end": 1548.898,
#     "speaker": "Speaker_21",
#     "text": "of when we think of these three P's of Gemini, personal, proactive, powerful, the proactive is all about this idea of like, why do I always have to be the one talking to"
#   },
#   {
#     "start": 1548.898,
#     "end": 1549.218,
#     "speaker": "Speaker_113",
#     "text": "AI? Bye."
#   },
#   {
#     "start": 1549.466,
#     "end": 1551.666,
#     "speaker": "Speaker_21",
#     "text": "Like there's times you want it to talk to you, right?"
#   },
#   {
#     "start": 1551.926,
#     "end": 1570.326,
#     "speaker": "Speaker_19",
#     "text": "Absolutely. bring you things. I think ultimately for us, think what will be true success for Gemini is like, how much time does it save you in your day? Absolutely. How much money does it save you? And these are the things you start to think about on the proactive side that are really interesting. So this is a little glance into the future of where that's going. Hey, look, thanks"
#   },
#   {
#     "start": 1570.326,
#     "end": 1580.164,
#     "speaker": "Speaker_15",
#     "text": "for shipping everything that you've been shipping. Yeah. All right? Yeah. I think behind the curtains, all of us have have been like you know cheering because you guys have been shipping like crazy and we love it."
#   },
#   {
#     "start": 1580.484,
#     "end": 1582.244,
#     "speaker": "Speaker_19",
#     "text": "Great, well thanks for the feedback too."
#   },
#   {
#     "start": 1583.224,
#     "end": 1584.184,
#     "speaker": "Speaker_0",
#     "text": "Now for the last"
#   },
#   {
#     "start": 1584.184,
#     "end": 1588.304,
#     "speaker": "Speaker_15",
#     "text": "segment what I wanted to do is because we have like a couple of minutes left. Yeah. I wanted to do something"
#   },
#   {
#     "start": 1588.304,
#     "end": 1589.004,
#     "speaker": "Speaker_114",
#     "text": "really quick."
#   },
#   {
#     "start": 1589.364,
#     "end": 1599.824,
#     "speaker": "Speaker_15",
#     "text": "Yeah. We're going to do a quick rapid fire. Yeah. Yeah. Right? If you're up for it. Sure. Sure. I'm going to put you in soup. I'll try to. I'll try to. And let's see where it gets to. Yeah. Sounds good. According to you what is the biggest lie in AI"
#   },
#   {
#     "start": 1599.824,
#     "end": 1601.784,
#     "speaker": "Speaker_115",
#     "text": "right now? The biggest lie. Yeah."
#   },
#   {
#     "start": 1602.144,
#     "end": 1603.284,
#     "speaker": "Speaker_116",
#     "text": "Ooh that's interesting."
#   },
#   {
#     "start": 1604.218,
#     "end": 1622.338,
#     "speaker": "Speaker_21",
#     "text": "I would say like there's a lot of talk of like is there too much compute and I all I can say from my side with the products I'm working on is we just need more Yes, I mean tpus gpus anything that the demand right now for this stuff is so high So I don't know if it's a lie or not or"
#   },
#   {
#     "start": 1622.338,
#     "end": 1625.058,
#     "speaker": "Speaker_19",
#     "text": "maybe but that's the first thing that came to mind sounds good Yeah,"
#   },
#   {
#     "start": 1625.058,
#     "end": 1631.758,
#     "speaker": "Speaker_15",
#     "text": "I've read that 25 to 30 percent of code at Google is written by yeah Yeah, what happens when it gets to 90 percent?"
#   },
#   {
#     "start": 1632.026,
#     "end": 1650.726,
#     "speaker": "Speaker_21",
#     "text": "Good question. mean one thing we're seeing right now is things like anti -gravity is the amount of Kind of PRs and just code for review that's coming in is becoming the real bottleneck Yeah, and so and it also is introducing interesting types of kind of almost like fatigue when you have to review so"
#   },
#   {
#     "start": 1650.726,
#     "end": 1652.766,
#     "speaker": "Speaker_22",
#     "text": "much Do you know what I mean? It's like in your"
#   },
#   {
#     "start": 1652.766,
#     "end": 1656.526,
#     "speaker": "Speaker_21",
#     "text": "your business. You're just getting pelted with things So that's probably what happens the"
#   },
#   {
#     "start": 1656.526,
#     "end": 1658.726,
#     "speaker": "Speaker_15",
#     "text": "orchestrator dilemma the orchestrator Your dilemma"
#   },
#   {
#     "start": 1658.516,
#     "end": 1659.876,
#     "speaker": "Speaker_117",
#     "text": "dilemma. Yeah, yeah,"
#   },
#   {
#     "start": 1660.256,
#     "end": 1662.276,
#     "speaker": "Speaker_118",
#     "text": "well said. All right, beautiful."
#   },
#   {
#     "start": 1663.036,
#     "end": 1668.156,
#     "speaker": "Speaker_15",
#     "text": "How do you define AGI and ASI? What is your definition? Because there is no defined definition. I've kind of given"
#   },
#   {
#     "start": 1668.156,
#     "end": 1682.236,
#     "speaker": "Speaker_21",
#     "text": "up on trying to define. So I'm not trying to get out of the question, but there's so many different definitions. mean, I think the things I'm watching right now with all these different products and the capabilities at the frontier are, what are the things that are surprising me? What"
#   },
#   {
#     "start": 1682.236,
#     "end": 1684.176,
#     "speaker": "Speaker_15",
#     "text": "is the last thing that's surprising me? I'm still,"
#   },
#   {
#     "start": 1684.538,
#     "end": 1686.538,
#     "speaker": "Speaker_21",
#     "text": "I I... think we're still living through like a"
#   },
#   {
#     "start": 1686.538,
#     "end": 1698.758,
#     "speaker": "Speaker_19",
#     "text": "real internalization of like how much you can hand off to these models and that they can do and These long -running tasks and I'm seeing stuff almost every week I feel like since Christmas in New Year's Like I"
#   },
#   {
#     "start": 1698.758,
#     "end": 1700.898,
#     "speaker": "Speaker_119",
#     "text": "thought the frontier was here, but it's a little bit last"
#   },
#   {
#     "start": 1700.898,
#     "end": 1702.858,
#     "speaker": "Speaker_120",
#     "text": "three months have been just why it's totally changed"
#   },
#   {
#     "start": 1702.858,
#     "end": 1704.998,
#     "speaker": "Speaker_19",
#     "text": "Yeah, yeah, I feel like we're in another acceleration"
#   },
#   {
#     "start": 1704.998,
#     "end": 1708.818,
#     "speaker": "Speaker_15",
#     "text": "awesome one skill that will be more valuable in the AI first world according"
#   },
#   {
#     "start": 1708.818,
#     "end": 1709.218,
#     "speaker": "Speaker_121",
#     "text": "to you"
#   },
#   {
#     "start": 1709.218,
#     "end": 1713.682,
#     "speaker": "Speaker_19",
#     "text": "That's interesting. You know a lot of people are saying taste I right think that's true. think another one though I"
#   },
#   {
#     "start": 1713.682,
#     "end": 1714.442,
#     "speaker": "Speaker_21",
#     "text": "would say is,"
#   },
#   {
#     "start": 1715.082,
#     "end": 1717.722,
#     "speaker": "Speaker_19",
#     "text": "I think some notion of like being"
#   },
#   {
#     "start": 1717.722,
#     "end": 1719.002,
#     "speaker": "Speaker_21",
#     "text": "able to reinvent yourself."
#   },
#   {
#     "start": 1719.382,
#     "end": 1721.402,
#     "speaker": "Speaker_122",
#     "text": "To live in the AI first world. To live in the AI"
#   },
#   {
#     "start": 1721.402,
#     "end": 1737.562,
#     "speaker": "Speaker_21",
#     "text": "first world, to understand these tools. I think sometimes, maybe sometimes people's identity gets tied to a certain job that they do. I think people that are kind of able to kind of reinvent themselves and change with it is going to be maybe maybe one"
#   },
#   {
#     "start": 1737.562,
#     "end": 1745.222,
#     "speaker": "Speaker_15",
#     "text": "of the the. top skills. I've been creating a lot of content talking about everyone becoming AI generalist, AI first problem solvers. Solve problems,"
#   },
#   {
#     "start": 1745.482,
#     "end": 1747.342,
#     "speaker": "Speaker_123",
#     "text": "think AI first. Yes. That's how you win."
#   },
#   {
#     "start": 1747.442,
#     "end": 1749.362,
#     "speaker": "Speaker_124",
#     "text": "I think that's wise. I think that's right. Awesome."
#   },
#   {
#     "start": 1749.782,
#     "end": 1753.382,
#     "speaker": "Speaker_15",
#     "text": "What's actual thing about agents that nobody's talking about?"
#   },
#   {
#     "start": 1753.942,
#     "end": 1772.206,
#     "speaker": "Speaker_19",
#     "text": "Oh, that's interesting. I would expect us to be having many more conversations about like the audit trails of agents. There's some interesting startups that are starting to be in this space, but I think I think because because agents have only really started working in the last 60 days or so, there's like a set of kind of stuff around the"
#   },
#   {
#     "start": 1772.206,
#     "end": 1773.406,
#     "speaker": "Speaker_21",
#     "text": "harness and"
#   },
#   {
#     "start": 1773.406,
#     "end": 1777.426,
#     "speaker": "Speaker_19",
#     "text": "being able to kind of understand what did the agent do that I feel like is kind"
#   },
#   {
#     "start": 1777.426,
#     "end": 1778.706,
#     "speaker": "Speaker_21",
#     "text": "of under explored right now."
#   },
#   {
#     "start": 1779.046,
#     "end": 1780.986,
#     "speaker": "Speaker_15",
#     "text": "Makes sense. What are the top AI tools and workflows"
#   },
#   {
#     "start": 1780.986,
#     "end": 1781.966,
#     "speaker": "Speaker_125",
#     "text": "that you use every day?"
#   },
#   {
#     "start": 1782.426,
#     "end": 1784.426,
#     "speaker": "Speaker_19",
#     "text": "Oh man, a lot of the ones I showed you today. Yeah,"
#   },
#   {
#     "start": 1784.546,
#     "end": 1786.446,
#     "speaker": "Speaker_20",
#     "text": "for sure. I mean, across"
#   },
#   {
#     "start": 1786.446,
#     "end": 1792.554,
#     "speaker": "Speaker_19",
#     "text": "our teams, everyone's in kind of Gemini, AI Studio. There's There's, I'm in more and more meetings where,"
#   },
#   {
#     "start": 1792.874,
#     "end": 1793.034,
#     "speaker": "Speaker_126",
#     "text": "know,"
#   },
#   {
#     "start": 1793.534,
#     "end": 1810.454,
#     "speaker": "Speaker_19",
#     "text": "if you get any kind of deck, it's something created in notebook, but most of the time it's a prototype you can play with and it maybe is a stitch thing or maybe, so that's whole set of things. I also try to play with a lot of just other stuff. I'm very interested, every Monday I kind of write a note to the team of here's all the cool stuff I saw in AI."
#   },
#   {
#     "start": 1811.674,
#     "end": 1821.26,
#     "speaker": "Speaker_21",
#     "text": "And maybe it sounds a little bit like the podcast you're listening to in gym, I'm just like trying to stay on top of it all. But yeah, I'm really trying to learn right now because it's changing so fast. So you"
#   },
#   {
#     "start": 1821.26,
#     "end": 1823.16,
#     "speaker": "Speaker_127",
#     "text": "also are learning every single day? day,"
#   },
#   {
#     "start": 1823.4,
#     "end": 1825.34,
#     "speaker": "Speaker_128",
#     "text": "every day. Beautiful. Are there any things"
#   },
#   {
#     "start": 1825.34,
#     "end": 1827.54,
#     "speaker": "Speaker_15",
#     "text": "that you use that the world has not seen yet?"
#   },
#   {
#     "start": 1828.954,
#     "end": 1831.194,
#     "speaker": "Speaker_129",
#     "text": "Yes, quite a few. Can I know about them?"
#   },
#   {
#     "start": 1831.374,
#     "end": 1832.994,
#     "speaker": "Speaker_15",
#     "text": "I can turn the cameras off if you want to."
#   },
#   {
#     "start": 1833.374,
#     "end": 1840.994,
#     "speaker": "Speaker_21",
#     "text": "I mean, the one at some point, I can't wait to get it. It's been out to India a little bit, I think, but it's a project in Google Labs called Google Beam."
#   },
#   {
#     "start": 1841.574,
#     "end": 1842.574,
#     "speaker": "Speaker_130",
#     "text": "Have you seen this thing? No."
#   },
#   {
#     "start": 1842.874,
#     "end": 1845.054,
#     "speaker": "Speaker_21",
#     "text": "OK, so imagine like a 55,"
#   },
#   {
#     "start": 1845.274,
#     "end": 1846.614,
#     "speaker": "Speaker_19",
#     "text": "65 inch screen. Oh yeah, screen."
#   },
#   {
#     "start": 1846.934,
#     "end": 1848.854,
#     "speaker": "Speaker_15",
#     "text": "The 3D screen. Yeah,"
#   },
#   {
#     "start": 1849.014,
#     "end": 1854.95,
#     "speaker": "Speaker_19",
#     "text": "this team is so ambitious. It's an amazing team. They're trying to solve teleportation. Yeah. So"
#   },
#   {
#     "start": 1854.95,
#     "end": 1856.87,
#     "speaker": "Speaker_131",
#     "text": "it's a really, really good"
#   },
#   {
#     "start": 1856.87,
#     "end": 1864.77,
#     "speaker": "Speaker_19",
#     "text": "one to go after. And I think we've cracked it. So those devices will start shipping later this year. Can't wait. making them with HP, so"
#   },
#   {
#     "start": 1864.77,
#     "end": 1865.27,
#     "speaker": "Speaker_21",
#     "text": "it's gonna be fun."
#   },
#   {
#     "start": 1865.79,
#     "end": 1871.79,
#     "speaker": "Speaker_15",
#     "text": "Beautiful, thank you so much, Josh. This was super fun. Thank you. I'm sure a lot of people are gonna learn a lot. And I will see you soon."
#   },
#   {
#     "start": 1871.97,
#     "end": 1873.75,
#     "speaker": "Speaker_132",
#     "text": "Sounds great. Thanks for the time. Thank you."
#   },
#   {
#     "start": 1873.83,
#     "end": 1874.23,
#     "speaker": "Speaker_133",
#     "text": "Yeah, see ya."
#   },
#   {
#     "start": 1876.73,
#     "end": 1878.41,
#     "speaker": "Speaker_15",
#     "text": "Is Rishi super pissed at us already?"
#   },
#   {
#     "start": 1879.19,
#     "end": 1881.25,
#     "speaker": "Speaker_134",
#     "text": "Yes, yes. Have you been"
#   },
#   {
#     "start": 1881.25,
#     "end": 1882.51,
#     "speaker": "Speaker_135",
#     "text": "cutting the time of time up?"
#   }
# ]

# %%
for item in transcript:
    print(f"[{item['start']:.2f}-{item['end']:.2f}] {item['speaker']}: {item['text']}")
# Out:
# [0.00-4.18] Speaker_0: Most people are not even using 1 % of what Google
# [4.18-4.76] Speaker_1: has built.
# [6.49-20.43] Speaker_0: While the whole world has been focused on a damn chatbot, Google has been building something much, much larger. I'm talking about a tool where you can enter 100 pages of notes and it converts all of that into a cinematic video in just 60 seconds.
# [20.67-21.51] Speaker_2: A tool where
# [21.51-29.45] Speaker_0: you can just enter one sentence and convert the whole thing into a fully working app in just a few minutes. And there's one
# [29.45-31.17] Speaker_3: tool where you can just enter your
# [31.17-39.45] Speaker_0: website's URL and in one click, it will generate the whole week's marketing on the go. Now here is what is different about this video. You know
# [39.45-41.49] Speaker_4: that I don't usually show up like this.
# [41.77-47.49] Speaker_0: It's usually my AI clone that creates all the content for me. Of course, my thoughts are real.
# [47.77-49.43] Speaker_5: But for this video, it had
# [49.43-50.01] Speaker_6: to be different.
# [50.53-53.05] Speaker_0: So I flew to meet someone very interesting.
# [53.55-54.89] Speaker_7: Meet Josh Woodward.
# [55.25-65.39] Speaker_0: He is the person behind Google Gemini. He is also the person who runs the Google Gemini. Google LAMP team that built notebook LAMP and of course he is also the person behind Google AI
# [65.39-67.89] Speaker_8: Studio. In fact Time magazine just
# [67.89-71.85] Speaker_0: rated him as one of the top 100 most influential AI
# [71.85-72.97] Speaker_9: figures in the world.
# [73.33-91.81] Speaker_0: We didn't just talk about it, I asked him to show me things live in front of a camera. And if you're wondering this is some basic tutorial, guess what it's not. Josh ended up speaking about something that is still being built and most people in the world haven't heard about it. And you know what? You're gonna hear all about it.
# [92.07-93.13] Speaker_10: So, let's get started.
# [94.17-96.31] Speaker_0: Okay Josh, first of all, thank you very much for
# [96.31-98.31] Speaker_11: doing this. Very excited. Good to see you in
# [98.31-100.19] Speaker_12: flesh. Because I've been seeing on Twitter.
# [101.51-102.27] Speaker_13: Right? That was great
# [102.27-104.31] Speaker_14: to meet you, first of all. Absolutely. So
# [104.31-106.41] Speaker_0: first question that I have is, you have a very interesting
# [106.41-110.33] Speaker_15: job. You run the Gemini app, the Gemini team, and you also
# [110.33-110.93] Speaker_16: run the labs.
# [111.35-111.59] Speaker_17: Right.
# [112.60-114.84] Speaker_0: My question is what keeps you awake? Is that
# [114.84-116.66] Speaker_15: the Gemini team that keeps you awake or the labs?
# [116.78-120.88] Speaker_0: Because you guys have been shipping at a velocity which is unprecedented. I don't
# [120.88-122.60] Speaker_18: have a different word for this. Yes, yes, yes.
# [123.26-124.70] Speaker_19: I actually sleep pretty well right
# [124.70-124.92] Speaker_20: now.
# [126.06-126.86] Speaker_20: I mean,
# [127.04-129.92] Speaker_21: both are extremely fun. They're full on for sure.
# [131.10-132.82] Speaker_22: But no, they don't keep me up.
# [133.02-135.04] Speaker_23: There's a lot to ship though.
# [135.52-142.99] Speaker_21: I feel like it's one of the best parts of the job right now. Every week there's some new capability. capability and is how do you kind of turn it into a product or a feature and get it out.
# [144.01-145.43] Speaker_0: Look, one thing that is happening
# [145.43-178.15] Speaker_15: is every time you ship a new labs product, every time you ship a new feature inside of Gemini, there is one narrative that propels across the internet and that is, oh, Pomele is going to replace marketers, oh, Liriya is going to replace a lot of music people, right? Anti -gravity is going to replace a lot of engineers. So there is this narrative built across AI that's going to replace a a lot of people people. and everything around it. So my big question that I have for you is to all those people who are worried, what is one line of advice that you have for everyone? And what do you think people should do to win in the AI first world?
# [178.53-180.13] Speaker_24: Yeah, well it's interesting because how we
# [180.13-190.19] Speaker_19: think of a lot of these tools, they are tools actually. And so a lot of what we do, one of our values on both the teams is we talk about how we co -create. So whether it's Pomele, we actually are working
# [190.19-190.53] Speaker_25: with
# [190.53-196.54] Speaker_19: marketing and creative directors. on that product, notebook LM, that came from working with authors,
# [197.64-205.04] Speaker_19: anti -gravity, flow for filmmaker. You can kind of go down the list, right? So I think that would be how we think about it at a high level
# [205.04-205.58] Speaker_26: is more,
# [206.08-228.09] Speaker_19: how do we get this tool in the hands of either a professional who generally becomes way more prolific or these tools are incredible about really lowering the barriers where people can sort of do things they never could before. So you mentioned Lyria and music. I'm terrible at music, but I can kind of make stuff with Liria. And it's not going to win any awards or anything, but it's fun for my friends. I wouldn't be
# [228.09-229.71] Speaker_27: surprised though. No, no, no, no.
# [230.19-236.07] Speaker_19: I mean, the other thing I would say though, is with a lot of this stuff, my best advice, you said kind of one line
# [236.07-237.91] Speaker_21: advice, you just got to try it
# [237.91-253.49] Speaker_19: all the time and see kind of where that frontier is. Cause that frontier keeps moving out and it's jagged, right? And so that would be the way I would say is is try it. these tools, see if they fit in your workflow today. In some cases they might, in some cases they won't yet, but that would be the main
# [253.49-255.69] Speaker_28: advice. So basically playing with AI tools,
# [255.85-257.65] Speaker_15: orchestrating them is the biggest I think
# [257.65-259.65] Speaker_29: that's right. And I think the word you just said is
# [259.65-261.67] Speaker_19: very good, which is kind of play. And I think
# [261.67-267.19] Speaker_21: that's how we try to approach a lot of things, whether it's on Gemini or Labs or AI Studio, is kind of this mindset of play.
# [267.61-269.65] Speaker_19: And you're kind of figuring out, like, what is this thing
# [269.65-275.62] Speaker_21: good for? You know what I mean? In some cases, you're like, nah, this is bad. And In some g cases, - like, I can't live without this.
# [275.80-277.68] Speaker_19: You know, and then you're trying to figure out kind of in between.
# [278.30-284.30] Speaker_15: No, that makes a lot of sense. In fact, one other question that comes quite a lot for people is, every time they think about, hey,
# [284.40-285.38] Speaker_30: you have to play
# [285.38-324.05] Speaker_15: with these AI tools and you have to be on top of it. you know, there's a lot of vibe coding that people have been doing, a lot of agent building like Opel has been doing that really well. Gem has the power of building an agent as well. I think Google AI Studio was initially built for developers. Now, I use that quite a lot. Yeah, Yeah. right. wipe code using build and then anti -gravity dropped. So there is this also sentiment, especially for people who can't code. Right. Saying that, hey, if I want to win the AI race, if I want to win in this AI first world, I need to be technical. I need to be a developer. What is your sense on that? How can someone who's not technical as well have the fair shot at winning versus technical people as well? Yeah, it's interesting. What
# [324.05-332.07] Speaker_19: we're seeing right now, folks that are maybe more professionally trained as a software engineer. year, here. they're wielding, you know, five, ten, 15 agents at
# [332.07-333.81] Speaker_31: a time doing incredible things.
# [334.21-339.75] Speaker_19: But I think the other part that's happening at the exact same time is sort of the future of software development
# [339.75-340.29] Speaker_32: really
# [340.29-356.74] Speaker_19: democratizing in really interesting ways. And I mean, you talked about AI Studio, one of the most common things happening right now inside Google, people take a screenshot of their product, say Gmail, and you may have a marketing person or UX or a PIA. or anybody on the team that's not
# [356.74-359.34] Speaker_21: quote unquote technical, drop that into AI Studio,
# [359.98-389.91] Speaker_19: start adding features and sort of hacking on it. Absolutely. Now, we're not at a point yet where you can hit a button and that goes to production, but we're not far. And I think what's interesting is thinking about even like how the relationships between the different functions is changing. And at least for us, a lot of our teams, there's this blurring of people who are like, part engineer, part PM, Part part. UX, do you know what I mean? And those people are oftentimes kind of creating the most interesting kind of breakthrough products. I've been seeing
# [389.91-392.19] Speaker_15: my designers kind of shipping products.
# [393.55-396.69] Speaker_15: My PM's kind of building products that's going into production.
# [397.99-398.99] Speaker_33: Engineers designing.
# [399.97-404.07] Speaker_15: It's absolutely insane. It's happening live. It is. It is just
# [404.07-405.39] Speaker_19: kind of unfolding in front of us.
# [406.03-414.01] Speaker_15: No, look, I think you guys have been shipping like like this. crazy. The most of the time that I would like to spend going forward is for me to see stuff on how you use the stuff that
# [414.01-415.97] Speaker_34: you build. let's do that. OK,
# [416.09-442.05] Speaker_19: that sounds good. we can maybe cut to the demo here. Let's I thought we could maybe just start. You've been on this site, and I'm sure a lot of your listeners have too. But this is the Google Lab site. As far as I know, it's the only Google site with a hot pink banner at the top. But it's kind of all our stuff. So you know, pomel, CC, Mixed the export, Bull. Opal, you can kind of go through and kind of check it all out. Absolutely. And anyways, everybody can check that out. It's really fun. But maybe what I thought you could start
# [442.05-443.97] Speaker_35: with is Pomele. I don't know if you'll notice
# [443.97-447.95] Speaker_15: this. Internet has been filled with videos about Pomele. It has. People
# [447.95-449.55] Speaker_36: have been loving it. Yeah,
# [449.81-453.63] Speaker_19: fun fact, the Pomele tweet, number one Google labs tweet in history.
# [453.91-455.97] Speaker_37: Insane. Number four tweet in Google's
# [455.97-457.81] Speaker_19: history. Wow. So it really took off.
# [458.43-460.04] Speaker_38: But did you guys think of it as as
# [460.01-465.90] Speaker_15: you guys are building it. Because I also wanted to understand how you guys think about labs projects and how do you run the team as well. But you get
# [465.90-468.14] Speaker_37: to it slightly. Yeah, maybe Pimeli's an interesting example. So
# [468.14-493.84] Speaker_19: we can do the demo. It's like as you're starting on something like this, we're very interested in how hard it is for small businesses to create marketing assets. Very true. And collateral and all the social stuff and everything. So it kind of started with a deceptively simple idea. And it was an experiment. was basically like, like I'll show you. you this next tab. is an organization in my hometown in Oklahoma City, OKC, called Restore OKC. And the idea was, could you
# [493.84-495.02] Speaker_21: just take the URL,
# [496.22-501.36] Speaker_19: restoreokc.org, and drop it into a tool, hit a button, and start getting creative assets.
# [501.78-503.56] Speaker_15: That's where it started. Can a tool be a marketing team?
# [503.88-542.60] Speaker_19: Well, we didn't even start there. We basically were like, can you even just extract interesting things? So here's what you do. You drop the tool in, and you get this thing called your business. business DNA. And you can see what there's the URL. Here's the font. Here's the color palette. Here's some of the assets from the website. And we're like, okay, that's kind of interesting because it's like one little step. You get all this value. And then we're like, okay, what if you could make campaigns out of this? And it just starts creating again, you look at all this stuff, you're going to have like the font, the sort of sort of assets, it kind of fits this organization actually does a lot of kind of food service and donations do - in the community. And then a few weeks ago, we dropped this feature called
# [542.60-543.20] Speaker_39: Photo Shoot.
# [543.62-545.74] Speaker_19: And this was the one that really popped.
# [546.68-547.46] Speaker_40: it's all over the internet.
# [548.10-573.42] Speaker_19: And the idea here was like, can you take assets from your sort of website, in this case, select an image. Here's all the assets off the web page. Let's pick this head of lettuce or something like this. And you can say, yeah, it looks good. And then basically what you can just kind of put these and temple it. So I just kind of zoomed ahead head here. here so you can see it. But now it's like, here's your piece of lettuce on all these interesting backgrounds. And all this stuff you can download and take it wherever you want, right?
# [573.90-575.06] Speaker_21: And that's kind of how
# [575.06-578.98] Speaker_19: this thing gets started. And now people are starting to use it like crazy.
# [580.42-584.82] Speaker_19: Everywhere. launched in 160 countries, so it's now spread out. India launch was
# [584.82-586.86] Speaker_41: wide. Yeah, it was.
# [587.10-589.06] Speaker_19: I agree. We were watching the dashboards
# [589.06-590.58] Speaker_42: of the TPUs very closely.
# [591.58-654.56] Speaker_19: But this is an example of how something Your starts again we're co -creating it with marketing people yeah we think of it as a tool we don't think of it as replacing people because this is actually something a lot of small businesses don't have access to photography like this or the time or the setup so it kind of creates this ability to kind of give someone sort of superpower in this case so that's one example another one is kind of interesting on the design side is a project called stitch I love it yeah yeah Yeah, yeah, cool. So this one's fun. The idea behind this is what if you could kind of describe kind of an interface you wanted? And you can see here it could be an app or a website. I kind of was working on one earlier. This is like a discover Oklahoma City again back to my hometown. you can see it's kind of an infinite canvas kind of idea. Nice little touch by the way design. See the little smile like that traces. Okay, so here's how it works. You're kind of in this thing and you can go in and literally just come in and edit these things, drag it around, you can describe sort of changes you want to make, and then we just added this feature recently which is sweet. Right click on this thing and make an instant
# [654.56-655.08] Speaker_43: prototype.
# [655.84-681.82] Speaker_19: Now you see this arrow just got added, that stitch almost like the AI's in the board with you starting to make things. It's going to go off and use the Gemini 3 model. Here it comes to turn this thing into actually a clickable prototype. So if I click in here, boom, here's like your trip plan, you can go back, you can go to some of your saved places. So again, this whole thing, what's also so cool about this is any of these screens, you can right
# [681.82-683.36] Speaker_21: click and just grab the code.
# [684.26-688.44] Speaker_19: And it'll pull this up and you've got all the front end code ready to go. So while Stitch
# [688.44-692.18] Speaker_15: is actually a design first tool, it's in a way being built
# [692.18-693.52] Speaker_44: using code. Exactly.
# [694.12-698.33] Speaker_15: So it's vibe coding, but with a vibe design interface. It's like an inception. exception
# [698.33-700.61] Speaker_45: thing here. Yeah, and
# [700.61-703.73] Speaker_21: I think what people are finding here, you mentioned this earlier, it's like,
# [704.29-705.37] Speaker_46: who's using Stitch?
# [706.25-708.37] Speaker_19: This is a whole category we think of vibe design.
# [709.19-723.25] Speaker_21: People that are using it are not, designers are using it, but you also have an engineer. who never could have maybe done front end codes, back end engineer that comes to it. You're having people take this into AI studio and then start doing things. So you're getting all these really
# [723.25-725.22] Speaker_47: interesting combinations. Now you can do that to
# [725.22-725.80] Speaker_15: antigravity anti
# [725.39-725.39] Speaker_47: -
# [725.80-727.16] Speaker_15: as well. That's right, that's right.
# [727.20-727.34] Speaker_21: Yeah,
# [727.50-727.50] Speaker_15: yeah, yeah.
# [727.98-729.18] Speaker_21: That's right, you can drop it in there too.
# [729.76-737.32] Speaker_19: So this is kind of where Stitch is right now, kind of where it's going, it's kind of interesting. Maybe I'll just keep going, is that okay? please have lot of tabs lined up
# [737.32-737.34] Speaker_48: for
# [737.34-737.34] Speaker_19: you.
# [737.34-739.12] Speaker_48: Yeah, let's go for it, let's go for it. So
# [739.12-760.42] Speaker_19: this is, this is no book L.M. This is one of our first Google Labs products that sort of went viral with the podcast. I think the things that I'm very excited about where this is going next, so we've added obviously the the ability to do deep research right in notebook L.M. here's like a trip, like planning a trip to Hawaii. You can do deep research and grab 66 sources.
# [761.48-779.29] Speaker_19: And of course you can do your normal Q and A with it, but there's some new things that have come out that are pretty fun. So one is, I'm sure people have seen the infographics. One tap, this is pretty cool because Hawaii obviously several different islands. I love these little snapshots of each island that you can kind of check out. out so that's kind of fun. The newest thing
# [779.29-780.93] Speaker_21: though is actually these
# [780.93-793.01] Speaker_19: cinematic video overviews. So what's really cool before I play it is imagine 66 sources in this case. Gemini is going to basically act as kind of an assistant director,
# [793.65-805.90] Speaker_21: put together a script with kind of like drama and plot and everything. It's going to come up with a visual style which you can customize if you want and then put it all to kind of audio and time it all up. So do you want to see a
# [805.90-807.36] Speaker_49: little of that? please. Let's do it.
# [807.60-813.72] Speaker_21: Put a little audio on here and I'll make it bigger. Now this is pretty cool. This was like a felt style it just came up with. This is the
# [813.72-815.70] Speaker_50: ocean, check this When you picture a trip to
# [815.70-817.78] Speaker_51: Hawaii, you probably imagine this,
# [818.42-821.64] Speaker_52: empty white sand beaches, perfect surf, and
# [821.64-823.56] Speaker_53: total isolation from daily stress.
# [824.30-826.42] Speaker_51: This equation shows the financial reality
# [826.42-827.18] Speaker_54: of that dream,
# [827.82-829.94] Speaker_53: a standard seven day trip for two people.
# [830.20-832.10] Speaker_51: factoring in place, launching.
# [832.46-844.50] Speaker_21: Now I'm going to pause for just a second because all of these are actually coded in the background. So Gemini is like, I should make an interactive chart that builds this bar chart, writes the code and then drops it in, which is kind
# [844.50-846.18] Speaker_55: of a cool... So it's basically
# [846.18-852.46] Speaker_15: converting an animation into a video. That's it. And the animation is... So the beauty of this world is everything is written
# [852.46-853.52] Speaker_56: using code. There you go.
# [853.94-859.90] Speaker_21: Wow. So as we go through it, we won't play the whole thing but I want to play you one more little section sec... but this I wanted to call out just because
# [859.90-862.12] Speaker_57: I thought you'd like that. Okay
# [862.12-863.32] Speaker_21: so is an expensive trip.
# [864.58-865.88] Speaker_58: I'm sure you're gonna fart it.
# [867.46-867.94] Speaker_59: Now
# [867.94-869.80] Speaker_19: check this out because then it's gonna
# [869.80-881.62] Speaker_51: go through. Blur the Hawaiian islands together into one identical flawless paradise. Behind those filtered photos each of the four main islands features radically different weather patterns. Okay
# [881.62-883.62] Speaker_19: so here's another example we take like a map.
# [884.25-888.31] Speaker_21: Convert it to code and kind of do this overlay and start connecting it this way So
# [888.31-896.45] Speaker_19: when we saw I remember the first time I saw this I was like whoa, this is new But it's kind of again this blurring and mixing of in this
# [896.45-897.43] Speaker_21: case some code
# [897.43-903.91] Speaker_19: some video some nano banana all coming together And I think what's amazing and kind of what's made notebooks such
# [903.91-907.97] Speaker_21: a fun project is just he helps you understand anything So
# [907.97-915.87] Speaker_19: whether it's planning a trip or you're a student or you're a teacher or you're a knowledge worker work or whatever, you just drop in the sources and then you can start making stuff with
# [915.87-921.49] Speaker_15: it. I think this is a perfect tool for people when they say that every person can have an AI tutor.
# [921.83-922.79] Speaker_60: Yes. I think this is it.
# [923.21-927.23] Speaker_19: That's how a lot of people are using it. That's exactly right. Yeah, quizzes in this thing are super popular.
# [927.55-945.45] Speaker_15: And so is the podcast. I will tell you how I use this, right? yeah. I'm geeking on AI and every single day I wake up with 100 updates. Yeah. So if I have found a way to ingest ingest all the updates into this, it converts that into a podcast and when I'm in the gym, I'm listening to the notebook L.M. podcast. Nice. Right? Now, I have a
# [945.45-947.65] Speaker_61: request for you. Okay. You guys
# [947.65-948.31] Speaker_62: shipped
# [948.31-952.67] Speaker_15: the CLI for Google Workspace. Can you please add notebook L.M. to that
# [952.67-954.59] Speaker_63: as well? So that I can automate
# [954.59-956.77] Speaker_64: it. One of the top requests either CLI
# [956.77-958.45] Speaker_65: or MCP for notebooks. Please do.
# [958.69-960.77] Speaker_14: Okay, feature request noted. Now, people have
# [960.77-964.65] Speaker_15: been hacking this round. I actually do it by the way today by using browser use.
# [964.51-966.59] Speaker_66: Yeah, yeah, right, but I'm like,
# [966.67-968.63] Speaker_67: yeah, can you please make it in the air for
# [968.63-970.39] Speaker_68: me please? Okay, noted,
# [970.59-982.63] Speaker_19: noted. Okay, two more for you. That's okay, let's do a little genie and then we can jump over to Gemini. So, genie I think is one of those projects where you kind of have to see it to believe it. And I remember exactly where I was
# [982.63-984.15] Speaker_21: when I saw the first one, I was just like,
# [984.57-984.85] Speaker_69: what?
# [985.95-986.53] Speaker_69: I can't believe is possible. this What
# [986.53-987.41] Speaker_70: did we just made?
# [988.69-1026.51] Speaker_19: So, you know, the thing about Genie genie, is kind of a world -building kind of tool. It's very experimental right now. It's very limited in terms of even just how many people we can have on it. What's kind of fun is we built all these little worlds I love the cat one. You can try. The cat one's kind of fun, right? Yeah. Yeah I think the other thing that's kind of fun about Genie is you can bring your own, right? Yeah, so that's pretty fun too. This one's kind of one of my new favorites I've been using this one recently. This is like, you know, kind of a parrot or or whatever whatever flying through the Amazon. Now as this world gets built, it takes about 20, 25 seconds. You'll see the keys coming on here. It's kind of old school gaming, space bar to jump, you
# [1026.51-1028.53] Speaker_71: know, WASD to turn, you can
# [1028.53-1030.53] Speaker_72: change the camera angle. The GDA vice city is
# [1030.53-1032.07] Speaker_73: bad. That's right, that's right.
# [1032.45-1042.33] Speaker_19: And I think what's been fun is just watching because at the end of this, it'll record it and you can share the video. so there's a whole other kind of side of Genie which are people sharing these worlds. I've tried to put
# [1042.33-1044.39] Speaker_15: my... myself in one of these scenes as well. Oh
# [1044.39-1046.57] Speaker_74: nice, is it any good? It was pretty
# [1046.57-1048.39] Speaker_15: good actually. It's better than what I expected. Okay,
# [1048.47-1052.45] Speaker_21: so here's our bird. He's, oh wow, he's flying pretty fast. we're gonna try to make it
# [1052.45-1054.45] Speaker_22: through this tunnel. I think, yeah, there we go.
# [1054.49-1056.31] Speaker_21: Now we're on the other side and I'll hit space bar and I'm gonna
# [1056.31-1058.81] Speaker_19: start climbing, try to get to the top of this,
# [1059.31-1061.57] Speaker_75: whatever, a little room here. There's like a balinese
# [1061.57-1063.29] Speaker_76: - Check the shadow, see the shadow
# [1063.29-1065.21] Speaker_21: right over there. It's incredible. Yeah, it looks like
# [1065.21-1067.25] Speaker_19: we're somewhere, like Angkor Wat or
# [1067.25-1071.35] Speaker_21: something, right? Now I think what's What's amazing amazing state tomorrow as the about this is every frame is
# [1071.35-1073.33] Speaker_77: being generated. On the fly. On the fly. So,
# [1073.77-1078.91] Speaker_21: it's insane. When I turn this, I'm going to kind of steer him a little bit. That jungle's there. If we came back and flew through
# [1078.91-1080.85] Speaker_19: this again, that jungle may not be there.
# [1081.47-1082.99] Speaker_78: So it's not kept or got it. It's all
# [1082.99-1093.21] Speaker_21: generated in sort of truly in the generative sense. Every pixel is kind of streamed in this way. Now the other thing you'll notice, which is kind of fun, you see at the top there's this bar that's getting dangerously close to the end.
# [1093.21-1095.40] Speaker_19: This, our world is about to collapse. collapse.
# [1095.78-1097.34] Speaker_79: So right now the genie
# [1097.34-1111.16] Speaker_21: world only lasts 60 seconds and then they're gone. So what'll happen is it gets to the end here. Oh, I've never actually seen this little river back here. This is interesting. Okay. See how he just froze? Yeah. And now our world's like collapsing on us. We do that partly. could keep the consistency.
# [1111.50-1115.20] Speaker_19: That's about as long as it'll last partly cause we don't want to melt too many. Yeah. That's, that's what
# [1115.20-1117.06] Speaker_80: I was thinking. don't want to measure your genie. That's right.
# [1117.28-1128.84] Speaker_19: That's right. That's right. So anyway, this is, um, genie. We're super excited because because clearly this is a little bit of a toy right now in terms of the experiment we've built, but it shows kind of the potential we think of
# [1128.84-1129.52] Speaker_81: gaming,
# [1130.08-1140.22] Speaker_19: the potential maybe of entertainment, potential even of robotics and embodied AI, because as you're building these worlds, you're getting a feel for how to navigate them. So we'll see you a lot more from this in the coming
# [1140.22-1142.22] Speaker_15: years. The first thing that came to my mind when I saw Jeannie
# [1142.22-1143.56] Speaker_82: is I
# [1143.56-1145.46] Speaker_15: miss my old hometown, the way it
# [1145.46-1147.10] Speaker_83: looked. Oh yeah. Right?
# [1147.26-1153.60] Speaker_15: And I believe tech like this will enable me to preserve the place the way it is on a 3D view.
# [1154.00-1155.58] Speaker_84: And then I could actually go back.
# [1155.78-1157.58] Speaker_85: Yeah, yeah, yeah. Right? So it's
# [1157.58-1163.70] Speaker_15: like Google Earth. But 10 years behind, 15 years behind. And I preserve that forever. For my kids to see, for my
# [1163.70-1165.22] Speaker_86: grandkids to see. Yeah, yeah.
# [1165.60-1167.56] Speaker_87: Sort of captured in that world. Yes. So I can
# [1167.56-1171.62] Speaker_15: see a product, I'm sure you guys are thinking about it. A mix of Genie plus
# [1171.62-1173.60] Speaker_88: Google Earth. Yes, yeah. Right? We know
# [1173.60-1189.74] Speaker_19: it's so funny, back in California, in Mountain View, there used to be this big Google Earth display. You'd walk in, it was wraparound screens. You had a little joystick. Guess what the number one thing everyone would do? They'd go to their home town. it. And they would kind of zoom in. was satellite view.
# [1189.82-1193.54] Speaker_15: I had done that too. I mean, the first time when I came across Google Earth, I'd be
# [1193.54-1195.20] Speaker_89: like, can I find my home? And I did.
# [1196.12-1197.50] Speaker_90: yeah. Yeah, but this is
# [1197.50-1201.45] Speaker_19: cool because you could actually walk the streets. or I don't know become a parrot and fly
# [1201.45-1203.59] Speaker_91: around or something. you guys should have shipped this four or five
# [1203.59-1205.47] Speaker_15: years before so that GTFI could have made it
# [1205.47-1208.59] Speaker_92: earlier. man,
# [1208.77-1209.67] Speaker_93: I don't know, that's
# [1209.67-1213.71] Speaker_15: a different thing. No but we have done vibe design, we have done vibe code. Yeah. Now we are
# [1213.71-1215.75] Speaker_94: basically vibe gaming. Yeah, we've got world
# [1215.75-1217.73] Speaker_95: -building happening. This is God
# [1217.73-1219.73] Speaker_96: mode. Let me show you one last
# [1219.73-1244.86] Speaker_19: bit on just Gemini. We can rap here I guess. So I think nano banana obviously. Thank Thank you. you to India. was one of the first countries where it took off. It was just unbelievable. I would say I'll show you some various things. But I mean, one thing with Nanobanana 2 is obviously the text renderer. Text, yes. Just sets it apart. This is really fun. Viral trend is like gnolling things, separating it out into the component parts.
# [1245.94-1253.42] Speaker_19: But this has just become a thing. I think we'll see Nanobanana -type experiences for video video. for music, for voice,
# [1253.66-1254.66] Speaker_21: like this idea to just
# [1254.66-1258.94] Speaker_19: conversationally edit. It feels so natural, right? It's how it should work.
# [1259.88-1261.02] Speaker_15: It's like talking to a designer,
# [1261.34-1263.14] Speaker_97: right next to you. Yeah, that's right.
# [1263.28-1277.10] Speaker_19: And being able to kind of iterate on things goes back to some of the things we said about control and sort of that precision. So anyway, we're really excited about all the nano -banana growth and other usage. This one's kind of fun. You know, I threw in something, congrats on the T20, by the way.
# [1277.26-1279.02] Speaker_98: Hey, yes. when we were You're
# [1279.02-1299.18] Speaker_19: filming. filming this, I guess. But you can take something in Gemini now and just kind of create music very easily. And actually, maybe I'll just show you real quick how that comes up. It's super easy, because you just drop into Gemini and just say, like, create music. And you've got all these templates to choose from, right? And so here's one. One of my favorite ones is this thing called
# [1299.18-1299.78] Speaker_99: Bad Music.
# [1300.54-1302.16] Speaker_100: Bad Music. So you could throw
# [1302.16-1309.30] Speaker_21: in something simple, like India Champions T20, runs. runs, and then it'll just come back with something like this.
# [1312.06-1314.30] Speaker_101: Titans, the thunder of victory, the trajectory
# [1314.30-1316.44] Speaker_102: of planetary alignment has
# [1316.44-1318.18] Speaker_103: blessed this sporting endeavor.
# [1318.90-1346.93] Speaker_21: Okay, so it's gonna go on for 30 seconds. I was like talking about how great the victory was and everything, but I think this is again, 30 seconds. Eventually these will get longer. Eventually you'll have more of a control kind of part to it. Just a couple of weeks ago we announced we've acquired this company, producer AI. It's very good at this kind of back and forth iterative music. So I'm very excited about where music's gonna go. And part of it's entertainment and fun. mean, this song's never gonna win awards or anything, but it's more like,
# [1347.45-1348.93] Speaker_104: that one WhatsApp share that you
# [1348.93-1349.93] Speaker_105: do with your friends. That's it.
# [1350.21-1354.03] Speaker_21: You drop it in the group chat with your buddies and it's really fun.
# [1354.71-1356.01] Speaker_19: The other thing we're seeing actually,
# [1356.59-1366.60] Speaker_21: teachers and students are using it. Sometimes you can learn by a song or kind of the way kind of a melody works. And so that's a whole other different. a different branch of this, which is really interesting, kind
# [1366.60-1371.02] Speaker_19: of like a learning side to it. So that's Leria and kind of music in Gemini.
# [1372.04-1385.90] Speaker_19: You had asked about personal intelligence. wanted to show you this one. So a couple of weeks ago, I lost my goggles for swimming. So I like, oh man, what's happening? I basically did this search, what are the most comfortable prescription goggles you can buy?
# [1387.14-1425.81] Speaker_19: And what's cool about this is, so Gemini starts structuring, but structuring this, it's very neat, right? Top overall, best custom fit. All of these images, this is actually hooked up to Google Shopping Graph. Literally billions of items, where you can see you get like the ratings, the pricing. If I click on one of these, it'll actually, I can go out and buy this. Oh, that's sweet. It's all kind of neatly integrated. So that's kind of like the base experience, which is like awesome. And then you can kind of scroll down and it's like, oh man, what's my prescription? I have no No idea. And then here it goes, because I've opted into personal intelligence, you last went to the optometrist on February 11th, 2021. I should probably go back, that's been a while.
# [1426.59-1428.45] Speaker_106: Is that pulling from an email? This is pulling
# [1428.45-1432.45] Speaker_19: from my email and a photo of the prescription I took a picture of.
# [1432.69-1434.51] Speaker_107: That is insane. It's incredible, right?
# [1434.75-1438.15] Speaker_19: And again, this is a feature you have to opt into. So this won't just happen.
# [1438.57-1440.21] Speaker_21: You've got to turn it on. I turned it on.
# [1440.59-1449.60] Speaker_19: And then you can see like right eye, there it is. is, left eye there it is. And it's like, oh, by the way, you also have on these Warby Parker glasses you bought in August, which is these are the ones I'm wearing right now.
# [1450.68-1462.48] Speaker_19: But this starts to show the examples of like, how powerful it is if you wanna connect this stuff. And it's we see Gemini being this personal, proactive, powerful assistant that's working
# [1462.48-1462.98] Speaker_108: for you.
# [1463.44-1511.75] Speaker_19: And in this case, I was like, I would have just looked through my email or my gallery forever to find me. for It's so hard to find these kind of things. So it's like instant retrieval. The other thing we're finding people are using it a lot for. I'll show you this kind of fun was, remind me about my past visits to India before this trip. And so here it is, like here's when you were in Delhi, Bangalore, Mumbai, Hyderabad, you went to Mathura and Jaipur. sweet. And then what's kind of fun is like, oh show me my photos from Jaipur. It's like, bam, there it is. So it's kind of this incredible, ability with personal intelligence to really make AI yours. And I think that's kind of the promise we see with something like this. So this is in the US today and rolling out very soon. The feedback on this has been very positive. So we're really excited to get this
# [1511.75-1513.49] Speaker_109: out. How far are we Josh
# [1513.49-1524.92] Speaker_15: from AI literally recommending our stuff proactively rather than us prompting it? For example, here you're talking about prescription. Yeah, that's because this has to be prompted and I think you do not know.
# [1525.20-1526.78] Speaker_110: But it could be a bunch of things. It
# [1526.78-1531.04] Speaker_15: could be proactive, for example. You have a flight, and you haven't booked
# [1531.04-1532.60] Speaker_111: your seat. Yeah,
# [1532.90-1534.82] Speaker_112: yeah, How far would it the car, like
# [1534.82-1538.34] Speaker_21: a taxi on the other side, whatever, rental car, whatever. You're reading the roadmap.
# [1538.84-1540.86] Speaker_22: Yeah? Okay, okay. Part
# [1540.86-1548.90] Speaker_21: of when we think of these three P's of Gemini, personal, proactive, powerful, the proactive is all about this idea of like, why do I always have to be the one talking to
# [1548.90-1549.22] Speaker_113: AI? Bye.
# [1549.47-1551.67] Speaker_21: Like there's times you want it to talk to you, right?
# [1551.93-1570.33] Speaker_19: Absolutely. bring you things. I think ultimately for us, think what will be true success for Gemini is like, how much time does it save you in your day? Absolutely. How much money does it save you? And these are the things you start to think about on the proactive side that are really interesting. So this is a little glance into the future of where that's going. Hey, look, thanks
# [1570.33-1580.16] Speaker_15: for shipping everything that you've been shipping. Yeah. All right? Yeah. I think behind the curtains, all of us have have been like you know cheering because you guys have been shipping like crazy and we love it.
# [1580.48-1582.24] Speaker_19: Great, well thanks for the feedback too.
# [1583.22-1584.18] Speaker_0: Now for the last
# [1584.18-1588.30] Speaker_15: segment what I wanted to do is because we have like a couple of minutes left. Yeah. I wanted to do something
# [1588.30-1589.00] Speaker_114: really quick.
# [1589.36-1599.82] Speaker_15: Yeah. We're going to do a quick rapid fire. Yeah. Yeah. Right? If you're up for it. Sure. Sure. I'm going to put you in soup. I'll try to. I'll try to. And let's see where it gets to. Yeah. Sounds good. According to you what is the biggest lie in AI
# [1599.82-1601.78] Speaker_115: right now? The biggest lie. Yeah.
# [1602.14-1603.28] Speaker_116: Ooh that's interesting.
# [1604.22-1622.34] Speaker_21: I would say like there's a lot of talk of like is there too much compute and I all I can say from my side with the products I'm working on is we just need more Yes, I mean tpus gpus anything that the demand right now for this stuff is so high So I don't know if it's a lie or not or
# [1622.34-1625.06] Speaker_19: maybe but that's the first thing that came to mind sounds good Yeah,
# [1625.06-1631.76] Speaker_15: I've read that 25 to 30 percent of code at Google is written by yeah Yeah, what happens when it gets to 90 percent?
# [1632.03-1650.73] Speaker_21: Good question. mean one thing we're seeing right now is things like anti -gravity is the amount of Kind of PRs and just code for review that's coming in is becoming the real bottleneck Yeah, and so and it also is introducing interesting types of kind of almost like fatigue when you have to review so
# [1650.73-1652.77] Speaker_22: much Do you know what I mean? It's like in your
# [1652.77-1656.53] Speaker_21: your business. You're just getting pelted with things So that's probably what happens the
# [1656.53-1658.73] Speaker_15: orchestrator dilemma the orchestrator Your dilemma
# [1658.52-1659.88] Speaker_117: dilemma. Yeah, yeah,
# [1660.26-1662.28] Speaker_118: well said. All right, beautiful.
# [1663.04-1668.16] Speaker_15: How do you define AGI and ASI? What is your definition? Because there is no defined definition. I've kind of given
# [1668.16-1682.24] Speaker_21: up on trying to define. So I'm not trying to get out of the question, but there's so many different definitions. mean, I think the things I'm watching right now with all these different products and the capabilities at the frontier are, what are the things that are surprising me? What
# [1682.24-1684.18] Speaker_15: is the last thing that's surprising me? I'm still,
# [1684.54-1686.54] Speaker_21: I I... think we're still living through like a
# [1686.54-1698.76] Speaker_19: real internalization of like how much you can hand off to these models and that they can do and These long -running tasks and I'm seeing stuff almost every week I feel like since Christmas in New Year's Like I
# [1698.76-1700.90] Speaker_119: thought the frontier was here, but it's a little bit last
# [1700.90-1702.86] Speaker_120: three months have been just why it's totally changed
# [1702.86-1705.00] Speaker_19: Yeah, yeah, I feel like we're in another acceleration
# [1705.00-1708.82] Speaker_15: awesome one skill that will be more valuable in the AI first world according
# [1708.82-1709.22] Speaker_121: to you
# [1709.22-1713.68] Speaker_19: That's interesting. You know a lot of people are saying taste I right think that's true. think another one though I
# [1713.68-1714.44] Speaker_21: would say is,
# [1715.08-1717.72] Speaker_19: I think some notion of like being
# [1717.72-1719.00] Speaker_21: able to reinvent yourself.
# [1719.38-1721.40] Speaker_122: To live in the AI first world. To live in the AI
# [1721.40-1737.56] Speaker_21: first world, to understand these tools. I think sometimes, maybe sometimes people's identity gets tied to a certain job that they do. I think people that are kind of able to kind of reinvent themselves and change with it is going to be maybe maybe one
# [1737.56-1745.22] Speaker_15: of the the. top skills. I've been creating a lot of content talking about everyone becoming AI generalist, AI first problem solvers. Solve problems,
# [1745.48-1747.34] Speaker_123: think AI first. Yes. That's how you win.
# [1747.44-1749.36] Speaker_124: I think that's wise. I think that's right. Awesome.
# [1749.78-1753.38] Speaker_15: What's actual thing about agents that nobody's talking about?
# [1753.94-1772.21] Speaker_19: Oh, that's interesting. I would expect us to be having many more conversations about like the audit trails of agents. There's some interesting startups that are starting to be in this space, but I think I think because because agents have only really started working in the last 60 days or so, there's like a set of kind of stuff around the
# [1772.21-1773.41] Speaker_21: harness and
# [1773.41-1777.43] Speaker_19: being able to kind of understand what did the agent do that I feel like is kind
# [1777.43-1778.71] Speaker_21: of under explored right now.
# [1779.05-1780.99] Speaker_15: Makes sense. What are the top AI tools and workflows
# [1780.99-1781.97] Speaker_125: that you use every day?
# [1782.43-1784.43] Speaker_19: Oh man, a lot of the ones I showed you today. Yeah,
# [1784.55-1786.45] Speaker_20: for sure. I mean, across
# [1786.45-1792.55] Speaker_19: our teams, everyone's in kind of Gemini, AI Studio. There's There's, I'm in more and more meetings where,
# [1792.87-1793.03] Speaker_126: know,
# [1793.53-1810.45] Speaker_19: if you get any kind of deck, it's something created in notebook, but most of the time it's a prototype you can play with and it maybe is a stitch thing or maybe, so that's whole set of things. I also try to play with a lot of just other stuff. I'm very interested, every Monday I kind of write a note to the team of here's all the cool stuff I saw in AI.
# [1811.67-1821.26] Speaker_21: And maybe it sounds a little bit like the podcast you're listening to in gym, I'm just like trying to stay on top of it all. But yeah, I'm really trying to learn right now because it's changing so fast. So you
# [1821.26-1823.16] Speaker_127: also are learning every single day? day,
# [1823.40-1825.34] Speaker_128: every day. Beautiful. Are there any things
# [1825.34-1827.54] Speaker_15: that you use that the world has not seen yet?
# [1828.95-1831.19] Speaker_129: Yes, quite a few. Can I know about them?
# [1831.37-1832.99] Speaker_15: I can turn the cameras off if you want to.
# [1833.37-1840.99] Speaker_21: I mean, the one at some point, I can't wait to get it. It's been out to India a little bit, I think, but it's a project in Google Labs called Google Beam.
# [1841.57-1842.57] Speaker_130: Have you seen this thing? No.
# [1842.87-1845.05] Speaker_21: OK, so imagine like a 55,
# [1845.27-1846.61] Speaker_19: 65 inch screen. Oh yeah, screen.
# [1846.93-1848.85] Speaker_15: The 3D screen. Yeah,
# [1849.01-1854.95] Speaker_19: this team is so ambitious. It's an amazing team. They're trying to solve teleportation. Yeah. So
# [1854.95-1856.87] Speaker_131: it's a really, really good
# [1856.87-1864.77] Speaker_19: one to go after. And I think we've cracked it. So those devices will start shipping later this year. Can't wait. making them with HP, so
# [1864.77-1865.27] Speaker_21: it's gonna be fun.
# [1865.79-1871.79] Speaker_15: Beautiful, thank you so much, Josh. This was super fun. Thank you. I'm sure a lot of people are gonna learn a lot. And I will see you soon.
# [1871.97-1873.75] Speaker_132: Sounds great. Thanks for the time. Thank you.
# [1873.83-1874.23] Speaker_133: Yeah, see ya.
# [1876.73-1878.41] Speaker_15: Is Rishi super pissed at us already?
# [1879.19-1881.25] Speaker_134: Yes, yes. Have you been
# [1881.25-1882.51] Speaker_135: cutting the time of time up?

# %% [markdown]
# ## Threshold Tuning
#
# Default speaker assignment uses `unique_speaker_similarity`: each new segment is compared to the current unique speaker centroids in timeline order. If the best similarity is above `speaker_similarity_threshold`, it joins that speaker; otherwise a new `Speaker_N` is created.
#
# If unknown speakers are merged together, raise `speaker_similarity_threshold`. If one speaker is split into many labels, lower it.
#
# You can also switch to global agglomerative grouping with `speaker_assignment_strategy="agglomerative"`. In that mode, lower `cluster_distance_threshold` to split more speakers and raise it to merge more speakers.
#
# If you add `user_voice.wav` and `USER` is over-assigned, raise `user_similarity_threshold`. If `USER` is missed, lower it in small steps such as `0.05`.

# %%
if OUTPUT_JSON_PATH.exists():
    loaded = json.loads(OUTPUT_JSON_PATH.read_text(encoding="utf-8"))
    print(f"Loaded {len(loaded)} transcript turns from {OUTPUT_JSON_PATH}")
    print(loaded[:1])
else:
    print("Output JSON has not been written yet.")
# Out:
# Loaded 348 transcript turns from /Users/saketm10/Projects/openclaw_agents/tests/voice_transcript.json
# [{'start': 0.0, 'end': 4.18, 'speaker': 'Speaker_0', 'text': 'Most people are not even using 1 % of what Google'}]
